# %% [markdown]
# # FINAL PROJECT: CS220 Spring 2020
# ## This is an individual exam. Do not work with a partner! Only change "submitter" netid information. Good luck.
# - For majority of the questions you need to replace "# Write your code here" comment with your own code.
# - There are 27 questions, each of which will be weighted 0.55 points.
# - Unlike projects, you will receive partial credit for a question as long as your code runs and produces an output for each question.
# - Unlike projects, you do not have access to "test.py". Instead, you can use "type_test.py". This file does not check if your answers are correct, but it checks if your answers are in the correct format.
# - "test.py" will run "lint.py" and deduct points for linting errors. You will lose 0.1 points for each linting error. You will only lose points for warnings, not convention messages (just like in P10). type_test.py does not run the linter, so check with lint.py before turning your work in. For more information about the linter as well as how to run the full linter to see all of the automatically generated advice and feedback, please check out the linting README: https://github.com/msyamkumar/cs220-projects/tree/master/linter.
# - General hint: if you see a lot of hints / write up before a question, it is likely to be difficult question.

# %%
# project: final
# submitter: hko26
# partner: none

# %%
# Recommended to use this cell to add import statements
import os, statistics
from collections import namedtuple
import requests, json, csv, sqlite3
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Just run this cell (it's just to make certain text red, but you don't need to understand it).
from IPython.core.display import display, HTML
display(HTML('<style>em { color: red; }</style> <style>.container { width:100% !important; }</style>'))
# Out:
# <style>em { color: red; }</style> <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Questions q1 to q10 address topics covered by projects P2 to P4.

# %% [markdown]
# ### Question 1: Is *map_dummy* an *iterable* data structure?
# - Complete the below code to demonstrate this.
# - Your cell should only output either *True* or *False*.
# - You *should not hardcode* the answer to this question.
# - Hint: recall how to do nothing in Python.

# %%
#q1: Is map_dummy an iterable data structure? True or False
map_dummy = map(str, [4,2,1.0])
try:
    for element in map_dummy:
        pass
    result = True
except TypeError as e:
    result = False
result
# Out:
# True

# %% [markdown]
# ### Question 2: Can we use a *list* as a *key in a dictionary*?
# - Complete the below code to demonstrate this.
# - Your cell should only output either *True* or *False*.
# - You *should not hardcode* the answer to this question.

# %%
#q2: Can we use a list as a key in a dictionary? True or False
test_dict = {}
test_list = [1, 2, 3]
try:
    test_dict[test_list] = "number"
    result = True
except TypeError as e:
    result = False
result
# Out:
# False

# %% [markdown]
# ### Question 3: Complete *falsify* function such that if *bool_list* contains one or more occurences of "False", returned value is False. Otherwise returned value is True.
# - You may add multiple lines of code inside the Falsify function.
# - Your code must work with a list of any length!
# - Your cell should only output a list containing two boolean values.

# %%
#q3: Complete *Falsify* function such that if *bool_list* contains one or more occurences 
#of "False", returned value is False. Otherwise returned value is True. 

def falsify(bool_list):
    # Write your code here
    for element in bool_list:
        if element == "False":
            return False
    return True

# Test 1
test_list = ["True", "True", "False", "True"]
test_1 = falsify(test_list)

# Test 2
test_list = ["True", "True", "Apple", "True"]
test_2 = falsify(test_list)
[test_1, test_2]
# Out:
# [False, True]

# %% [markdown]
# ### Use the following *data structure* to answer the next two questions *q4* and *q5*.

# %%
Student = namedtuple("Student", ["name", "id"])
data_struct = {
    "cs": [Student("John", "netID123"), Student("Martha", "netID123")],
    "econ": [Student("John", "netID5678_econ"), Student("Peter", "netID5679_econ")]
}

# %% [markdown]
# ### Question 4: What is the *ID* for *John from Economics*?
# - Your cell should only output the ID.

# %%
#q4: What is the ID for John from Economics?
data_struct["econ"][0].id
# Out:
# 'netID5678_econ'

# %% [markdown]
# ### Question 5: List the *names* of all students in *CS*.
# - Your answer should be in the form of a list.

# %%
#q5: List the names of all students in CS.
name_list = []
for data in data_struct["cs"]:
    name_list.append(data.name)
name_list
# Out:
# ['John', 'Martha']

# %% [markdown]
# ### Question 6:  Use *list slicing* to right rotate list [1,2,3,4] by three places.
# - Hint: When you rotate a list like [1,2,3,4] right by one place, you get [4,1,2,3].
# - Your answer should be in the form of a list.

# %%
#q6: Use list slicing to right rotate list [1,2,3,4] by three places
original_list = [1,2,3,4]

for i in range(3):
    temp_val = [original_list[-1]]
    rest_val = original_list[:3]
    original_list = temp_val + rest_val

original_list
# Out:
# [2, 3, 4, 1]

# %% [markdown]
# ## Analysing cereal.csv dataset (q7 to q14)
# ### Write a function that *reads* in the *cereal.csv* file and stores the data as a variable.
# - Make sure to write a generic function that takes csv file as input and returns the data (for reusability)
# - Download "cereal.csv" to the same local directory.
# - *Do not use any additional path* to your data file - this will *mess up grading*!
# - We will be using this variable through the next set of questions (q7 to q15).

# %%
# Function to read csv file
def read_csv(csv_filename):
    f = open(csv_filename, encoding="utf-8")
    reader = csv.reader(f)
    data = list(reader)
    return data

# %%
csv_cereal = read_csv("cereal.csv")
headers = csv_cereal[0]
data = csv_cereal[1:]

# %%
cereal_dict = {}
cereals = []
for header in headers:
    cereal_dict[header] = ''
for cereal in data:
    cereal_dict = {}
    cereal_dict['name'] = cereal[0]
    cereal_dict['mfr'] = cereal[1]
    cereal_dict['type'] = cereal[2]
    cereal_dict['calories'] = cereal[3]
    cereal_dict['protein'] = cereal[4]
    cereal_dict['fat'] = cereal[5]
    cereal_dict['sodium'] = cereal[6]
    cereal_dict['fiber'] = cereal[7]
    cereal_dict['carbo'] = cereal[8]
    cereal_dict['sugars'] = cereal[9]
    cereal_dict['potass'] = cereal[10]
    cereal_dict['vitamins'] = cereal[11]
    cereal_dict['shelf'] = cereal[12]
    cereal_dict['weight'] = cereal[13]
    cereal_dict['cups'] = cereal[14]
    cereal_dict['rating'] = cereal[15]
    cereals.append(cereal_dict)

# %% [markdown]
# ### Question 7: What is the *carbohydrate content* in the cereal named "*Cheerios*"?
# - Recall that you shouldn't hardcode the index for looking up a particular column's value.
# - Follow the index lookup for all further questions.
# - You should make sure to look up the index of the column using the csv header first.
# - Your cell should output a float.

# %%
#q7: What is the carbohydrate content in the cereal named "Cheerios"?
def get_carbo(cereal_name):
    for cereal in cereals:
        if cereal['name'] == cereal_name:
            return float(cereal["carbo"])
get_carbo("Cheerios")
# Out:
# 17.0

# %% [markdown]
# ### Question 8: What is the *cereal* with the *highest rating*?
# - Report your answer as a dictionary.
# - *key* as the *cereal name* and *value* as the *numerical rating*.

# %%
#q8: What is the cereal with the highest rating?
def get_highest_rating_cereal():
    result_dict = {}
    rating = 0
    final_rating = 0
    for cereal in cereals:
        if float(cereal['rating']) > rating:
            rating = float(cereal['rating'])
            result_dict[cereal['name']] = float(cereal['rating'])
    for cereal in result_dict:
        del(result_dict[cereal])
        break
        
    return result_dict
get_highest_rating_cereal()
# Out:
# {'All-Bran with Extra Fiber': 93.704912}

# %% [markdown]
# ### Question 9: Write *a function* that computes the *mininum, maximum, and average* for a given numerical column of the cereal data and returns these data as a dictionary. Report the basic statistics for the *fat* column.
# - Example output:
# ```result = {"min": 0.1, "max":5.2, "mean": 2.2}
# ```

# %%
#q9: Write a function that computes the mininum, maximum, and average for a given 
# numerical column of the cereal data and returns these data as a dictionary.
# Report the basic statistics for the fat column.

def find_stats(col_name):
    min_value = 0
    max_value = 0
    total_fat_list = []
    result_dict = {}
    for cereal in cereals:
        total_fat_list.append(float(cereal[col_name])) 
        if float(cereal[col_name]) < min_value:
            min_value = float(cereal[col_name])
        elif float(cereal[col_name]) > max_value:
            max_value = float(cereal[col_name])
    result_dict = {"min": min_value, "max": max_value, "mean" : statistics.mean(total_fat_list)}
    return result_dict

result = find_stats('fat')
result
# Out:
# {'min': 0, 'max': 5.0, 'mean': 1.0129870129870129}

# %% [markdown]
# ### Question 10: Find the *difference* between the *average sugar content* of all cereals that are rated below 30 and the ones above 50.
# - Your cell should output a float value.

# %%
#q10: Find the difference between the average sugar content of all cereals 
# that are rated below 30 
# and the ones above 50
below_30_list = []
above_50_list = []
for cereal in cereals:
    if float(cereal['rating']) < 30:
        below_30_list.append(float(cereal['sugars']))
    elif float(cereal['rating']) > 50:
        above_50_list.append(float(cereal['sugars']))
avg_sugar_below_30 = statistics.mean(below_30_list)
avg_sugar_above_50 = statistics.mean(above_50_list)
avg_sugar_below_30 - avg_sugar_above_50 # don't change this line
# Out:
# 8.783882783882785

# %% [markdown]
# ## Questions q11 to q14 address topics covered by projects P5 and P6.

# %% [markdown]
# ### Question 11: How many products are in the cereal dataset?
# - Your cell should output an int.

# %%
#q11: How many products are in the cereal dataset?
len(cereals)
# Out:
# 77

# %% [markdown]
# ### Question 12: What is the *product name* in the cereal data that has the *third highest rating*?
# - Hints:
#    - You need need to re-order your cereal data by ratings.
#    - Recall that the typical function you use for re-ordering has a parameter called *key*, which enables you to write a getter function for lookup of specific column value.
# - Your cell should output str value.

# %%
#q12: What is the product name in the cereal data that has the third highest rating?
cereal_dict = {}
for cereal in cereals:
    cereal_dict[cereal['name']] = float(cereal['rating'])
#https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
sorted_cereal_dict = sorted(cereal_dict.items(), key=lambda x: x[1])
sorted_cereal_dict[-3][0]
# Out:
# 'Shredded Wheat spoon size'

# %% [markdown]
# ### Question 13: What are *product names* that meet the following criteria:
# 1. *2 ≤ fat ≤ 5*
# 2. *rating ≥ 30*
# 3. *100 ≤ sodium ≤ 200*
# - Your answer should be a list with the items names (str) sorted in lexicographical order.

# %%
#q13: What are product names that meet the following criteria:
   # 2 ≤ fat ≤ 5
   # rating ≥ 30
   # 100 ≤ sodium ≤ 200
names_list = []
for cereal in cereals:
    if float(cereal['fat']) >= 2:
        if float(cereal['fat']) <= 5:
            if float(cereal['rating']) >= 30:
                if float(cereal['sodium']) >= 100:
                    if float(cereal['sodium']) <= 200:
                        names_list.append(cereal['name'])
names_list
# Out:
# ['Almond Delight',
#  'Clusters',
#  "Cracklin' Oat Bran",
#  'Fruit & Fibre Dates; Walnuts; and Oats',
#  'Life',
#  'Muesli Raisins; Peaches; & Pecans',
#  'Mueslix Crispy Blend',
#  'Oatmeal Raisin Crisp',
#  'Raisin Nut Bran']

# %% [markdown]
# ### Question 14: Write a function *find_word(keyword)* that returns a list of product names that have *keyword* in the product name.
# - Keyword match:
#   - should be *case insensitive*
#   - should be *complete match (not a substring match)*, with the exception of "'" and "-" (see below example for details)
#   - apply split(...) method for handling / eliminating "-" and "'" from the comparsion
#   - Hint: this question is all about extracting individual words from the product name and iterating over those words. It is likely that you will need nested loops.
# - *Order the list* with the highest rated cereal first and the lowest rated cereal last:
#   - Hint: you already did something similar for #q12. Reuse the same getter function here.
# - The match result should not consider substring match:
#   - Let's say keyword is "Apple", and product names are ["Apple pie", "Apple's seed", "Applewatch", "apple-pay", "apples"].
#   - In this example only "Apple pie", "Apple's seed", and "apple-pay" matches with keyword.
#   - "Applewatch" and "apples" are NOT qualified since there are additional letters concatenated to the keyword.

# %%
# q14: Write a function find_word(keyword) that returns a list of product names that have 
# keyword in the product name.

def find_word(keyword):
    match_list = []
    name_rating_dict = {}
    for cereal in cereals:
        name = cereal['name']
        rating = cereal['rating']
        splitted_word_list = cereal['name'].split(" ")
        for i in range(len(splitted_word_list)):
            if keyword == splitted_word_list[i]:
                name_rating_dict[name] = rating
            elif "'n'" in splitted_word_list[i]:
                edited_word = splitted_word_list[i].split("'n'")
                if keyword in edited_word:
                    name_rating_dict[name] = rating
            elif "-" in splitted_word_list[i]:
                edited_word = splitted_word_list[i].split("-")
                if keyword in edited_word:
                    name_rating_dict[name] = rating
    
    sorted_name_rating_dict = sorted(name_rating_dict.items(), key=lambda x: x[1])   
    for data in sorted_name_rating_dict:
        match_list.append(data[0])
    
    return match_list
        

# After creating the function, what is the result of find_word("Wheat")?
find_word("Wheat")
# Out:
# ['Crispy Wheat & Raisins',
#  'Wheat Chex',
#  'Frosted Mini-Wheat',
#  'Nutri-grain Wheat',
#  'Puffed Wheat',
#  'Cream of Wheat (Quick)',
#  'Shredded Wheat',
#  'Shredded Wheat spoon size',
#  "Shredded Wheat'n'Bran"]

# %%
csv_player = read_csv("player_data.csv")
headers = csv_player[0]
data = csv_player[1:]

# %%
player_dict = {}
player_data = []
for header in headers:
    player_dict[header] = ''
    
for player in data:
    player_dict = {}
    player_dict['name'] = player[0]  
    player_dict['year_start'] = player[1]
    player_dict['year_end'] = player[2]
    player_dict['position'] = player[3]
    player_dict['height'] = player[4]
    player_dict['weight'] = player[5]
    player_dict['birth_date'] = player[6]
    player_dict['college'] = player[7]
    player_data.append(player_dict)

# %% [markdown]
# ## Analysing player_data.csv dataset (q15 to q18)
# ## Questions q15 to q18 address topics covered by project P7.
#
# ### Read *player_data.csv* using the csv reading function that you already wrote.
# - Download the NBA players dataset "player_data.csv" to the same local directory.
# - *Do not use any additional path* to your data file - this will *mess up grading*!
# - We will be using this variable through the next set of questions (q15 to q18).
# - For all the questions you should *skip all players who have some entries in the column are missing* (i.e., some entry is just the empty string).
# - Consider writing a *cell* function to convert appropriate columns into their correct data type!

# %% [markdown]
# ### Question 15 : How many *complete players* in the dataset?
# - Reminder: skip all players who have some entries in the column are missing.
# - Hint: answer should be lower than 4550!
# - Your cell should output an int.

# %%
# q15: How many complete players in the dataset? skip all players who have some entries 
# in the column are missing. i.e. one or more of the entries is the empty string.
count = 0
for player in player_data:
    if (player['name'] != '') and (player['year_start'] != '') and (player['year_end'] != '') and (player['position'] != '') and (player['weight'] != '') and (player['birth_date'] != '') and (player['college'] != ''):
        player['year_start'] = int(player['year_start'])
        player['year_end'] = int(player['year_end'])
        player['weight'] = int(player['weight'])
        count += 1
count
# Out:
# 4213

# %% [markdown]
# ### Question 16: What are the *stats* for the player whose name is "*Michael Jordan*"?
# - Answer in the form of a dict.
# - See the example below:
# ```example = {'name': 'Alaa Abdelnaby',
#  'year_start': 1991,
#  'year_end': 1995,
#  'position': 'F-C',
#  'height': '6-10',
#  'weight': 240,
#  'birth_date': 'June 24, 1968',
#  'college': 'Duke University'}```

# %%
#q16: What are the stats for the player whose name is "Michael Jordan"?
for player in player_data:
    if player["name"] == "Michael Jordan":
        break
player
# Out:
# {'name': 'Michael Jordan',
#  'year_start': 1985,
#  'year_end': 2003,
#  'position': 'G-F',
#  'height': '6-6',
#  'weight': 195,
#  'birth_date': 'February 17, 1963',
#  'college': 'University of North Carolina'}

# %% [markdown]
# ### Question 17: What are the *stats* for the *players* whose college is *"University of Wisconsin"*?
# - Your output should be a list of dictionaries.
# - Each dictionary should be similar to the example in the previous question.
# - Hint: consider writing a bucketize function.

# %%
#q17: What are the stats for the players whose college is "University of Wisconsin"
player_list = []
for player in player_data:
    if player['college'] == "University of Wisconsin":
        player_list.append(player)
player_list
# Out:
# [{'name': 'Cory Blackwell',
#   'year_start': 1985,
#   'year_end': 1985,
#   'position': 'F',
#   'height': '6-6',
#   'weight': 210,
#   'birth_date': 'March 27, 1963',
#   'college': 'University of Wisconsin'},
#  {'name': 'Paul Cloyd',
#   'year_start': 1950,
#   'year_end': 1950,
#   'position': 'G-F',
#   'height': '6-2',
#   'weight': 180,
#   'birth_date': 'June 13, 1920',
#   'college': 'University of Wisconsin'},
#  {'name': 'Bobby Cook',
#   'year_start': 1950,
#   'year_end': 1950,
#   'position': 'G-F',
#   'height': '5-10',
#   'weight': 155,
#   'birth_date': 'April 1, 1923',
#   'college': 'University of Wisconsin'},
#  {'name': 'Sam Dekker',
#   'year_start': 2016,
#   'year_end': 2018,
#   'position': 'F',
#   'height': '6-9',
#   'weight': 230,
#   'birth_date': 'May 6, 1994',
#   'college': 'University of Wisconsin'},
#  {'name': 'Duje Dukan',
#   'year_start': 2016,
#   'year_end': 2016,
#   'position': 'F',
#   'height': '6-9',
#   'weight': 220,
#   'birth_date': 'December 4, 1991',
#   'college': 'University of Wisconsin'},
#  {'name': 'Gene Englund',
#   'year_start': 1950,
#   'year_end': 1950,
#   'position': 'F-C',
#   'height': '6-5',
#   'weight': 205,
#   'birth_date': 'October 21, 1917',
#   'college': 'University of Wisconsin'},
#  {'name': 'Michael Finley',
#   'year_start': 1996,
#   'year_end': 2010,
#   'position': 'G-F',
#   'height': '6-7',
#   'weight': 215,
#   'birth_date': 'March 6, 1973',
#   'college': 'University of Wisconsin'},
#  {'name': 'Paul Grant',
#   'year_start': 1999,
#   'year_end': 2004,
#   'position': 'C',
#   'height': '7-0',
#   'weight': 245,
#   'birth_date': 'January 6, 1974',
#   'college': 'University of Wisconsin'},
#  {'name': 'Claude Gregory',
#   'year_start': 1986,
#   'year_end': 1988,
#   'position': 'F',
#   'height': '6-8',
#   'weight': 205,
#   'birth_date': 'December 26, 1958',
#   'college': 'University of Wisconsin'},
#  {'name': 'Devin Harris',
#   'year_start': 2005,
#   'year_end': 2018,
#   'position': 'G',
#   'height': '6-3',
#   'weight': 192,
#   'birth_date': 'February 27, 1983',
#   'college': 'University of Wisconsin'},
#  {'name': 'Al Henry',
#   'year_start': 1971,
#   'year_end': 1972,
#   'position': 'C',
#   'height': '6-9',
#   'weight': 190,
#   'birth_date': 'February 9, 1949',
#   'college': 'University of Wisconsin'},
#  {'name': 'Doug Holcomb',
#   'year_start': 1949,
#   'year_end': 1949,
#   'position': 'F',
#   'height': '6-4',
#   'weight': 200,
#   'birth_date': 'February 9, 1925',
#   'college': 'University of Wisconsin'},
#  {'name': 'Kim Hughes',
#   'year_start': 1976,
#   'year_end': 1981,
#   'position': 'C',
#   'height': '6-11',
#   'weight': 220,
#   'birth_date': 'June 4, 1952',
#   'college': 'University of Wisconsin'},
#  {'name': 'Frank Kaminsky',
#   'year_start': 2016,
#   'year_end': 2018,
#   'position': 'F-C',
#   'height': '7-0',
#   'weight': 242,
#   'birth_date': 'April 4, 1993',
#   'college': 'University of Wisconsin'},
#  {'name': 'Marcus Landry',
#   'year_start': 2010,
#   'year_end': 2010,
#   'position': 'F',
#   'height': '6-7',
#   'weight': 230,
#   'birth_date': 'November 1, 1985',
#   'college': 'University of Wisconsin'},
#  {'name': 'Walt Lautenbach',
#   'year_start': 1950,
#   'year_end': 1950,
#   'position': 'G-F',
#   'height': '6-2',
#   'weight': 185,
#   'birth_date': 'November 17, 1922',
#   'college': 'University of Wisconsin'},
#  {'name': 'Jon Leuer',
#   'year_start': 2012,
#   'year_end': 2018,
#   'position': 'F',
#   'height': '6-10',
#   'weight': 228,
#   'birth_date': 'May 14, 1989',
#   'college': 'University of Wisconsin'},
#  {'name': 'Wes Matthews',
#   'year_start': 1981,
#   'year_end': 1990,
#   'position': 'G',
#   'height': '6-1',
#   'weight': 170,
#   'birth_date': 'August 24, 1959',
#   'college': 'University of Wisconsin'},
#  {'name': 'Kirk Penney',
#   'year_start': 2004,
#   'year_end': 2005,
#   'position': 'G',
#   'height': '6-5',
#   'weight': 220,
#   'birth_date': 'November 23, 1980',
#   'college': 'University of Wisconsin'},
#  {'name': 'Don Rehfeldt',
#   'year_start': 1951,
#   'year_end': 1952,
#   'position': 'F',
#   'height': '6-7',
#   'weight': 210,
#   'birth_date': 'January 7, 1927',
#   'college': 'University of Wisconsin'},
#  {'name': 'Scott Roth',
#   'year_start': 1988,
#   'year_end': 1990,
#   'position': 'F',
#   'height': '6-8',
#   'weight': 212,
#   'birth_date': 'June 3, 1963',
#   'college': 'University of Wisconsin'},
#  {'name': 'Dick Schulz',
#   'year_start': 1947,
#   'year_end': 1950,
#   'position': 'F-G',
#   'height': '6-2',
#   'weight': 192,
#   'birth_date': 'January 3, 1917',
#   'college': 'University of Wisconsin'},
#  {'name': 'Glen Selbo',
#   'year_start': 1950,
#   'year_end': 1950,
#   'position': 'G-F',
#   'height': '6-3',
#   'weight': 196,
#   'birth_date': 'March 29, 1926',
#   'college': 'University of Wisconsin'},
#  {'name': 'Greg Stiemsma',
#   'year_start': 2012,
#   'year_end': 2015,
#   'position': 'C',
#   'height': '6-11',
#   'weight': 260,
#   'birth_date': 'September 26, 1985',
#   'college': 'University of Wisconsin'},
#  {'name': 'Alando Tucker',
#   'year_start': 2008,
#   'year_end': 2010,
#   'position': 'F',
#   'height': '6-6',
#   'weight': 205,
#   'birth_date': 'February 11, 1984',
#   'college': 'University of Wisconsin'}]

# %% [markdown]
# ### Question 18: What is the average *weight* for each *position*?
# - Answer with a dictionary, mapping the key "position" to the value "average weight" (float type).
# - Average is the same as mean.

# %%
#q18: What is the average "weight" for each "position"?
player_dict = {}
for player in player_data:
    if (player['name'] == '') or (player['year_start'] == '') or (player['year_end'] == '') or (player['position'] == '') or (player['weight'] == '') or (player['birth_date'] == '') or (player['college'] == ''):
        continue
    position = player['position']
    weight = float(player['weight'])
    if position not in player_dict:
        player_dict[position] = [weight]
    else:
        player_dict[position].append(weight)
for key in player_dict:
    player_dict[key] = statistics.mean(player_dict[key])
player_dict
# Out:
# {'F-C': 222.91944444444445,
#  'C-F': 228.25615763546799,
#  'C': 242.2192118226601,
#  'G': 186.82811459027315,
#  'F': 217.98585690515807,
#  'F-G': 202.60487804878048,
#  'G-F': 197.01785714285714}

# %% [markdown]
# ## Analysing netflix_titles.html (to be converted to Python data structure) dataset (q19 to q21)
# ## Question q19 addresses topics covered by project P10.
#
# ### Question 19: Download and parse netflix_titles.html and write the data into a list-of-lists or list-of-dictionaries
# - This dataset *should not be manually* downloaded!
# - To download this html file, complete the below download function (this part is from project P10).
# - Next step is to parse the html data to store it in a data structure, either list-of-lists or list-of-dictionaries.
# - You need to use BeautifulSoup functions find() and find_all().
# - Recall that *table* tag contains *tr* tags for rows.
# - Recall that *tr* tags contain *td* tags for the actual data.
# - Recall that you can extract *text* from any tag.
# - The headers for this dataset are the following:
# ```
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']
# ```
# - This cell should output the following after successful parsing:
# ```
# ['Norm of the North: King Sized Adventure',
#  'Jandino: Whatever it Takes',
#  'Transformers Prime']
# ```

# %%
#q19: Download and parse netflix_titles.html.

#Follow the detailed steps given in the below function outline.
# Complete the missing parts in the below download function

def download(filename, url):
    # We do not download again if the file already exists
    if os.path.exists(filename):
        return (str(filename) + " already exists!")


    # Write your code here
    # Download the file from URL and save it in `filename`
    else:
        r = requests.get(url)
        r.raise_for_status()
        data = r.text
        f = open(filename, "w", encoding = "utf-8")
        f.write(data)
        f.close()

    return (str(filename) + " created!")

#Do not change this line
download("netflix_titles.html", \
         "https://raw.githubusercontent.com/msyamkumar/cs220-projects/master/spring20/final/netflix_titles.html")

def parse_html_contents(html_file):
    #To store the parsed data
    data = []
    
    # Open and read the html file
    data = open(html_file, "r", encoding = "utf-8")
    
    # Create a BeautifulSoup type
    doc = BeautifulSoup(data, "html.parser")
    
    # Find the dataset table
    # Write your code here
    table = doc.find_all("tr") 
    
    # Find the rows in the table. Hint: separate your header versus data processing here.
    # Write your code here
    netflix_header = []
    headers = doc.find("tr").find_all("td") 
    for header in headers:
        netflix_header.append(header.get_text())
    
    
    # Find data for header row: you can generate a list of str here (see above output for reference)
    # Write your code here
    netflix_data = []
    # Find data for the remaining rows:
    for i in range(len(table)):
        if i == 0:
            continue
        else:
            netflix_data.append(table[i].get_text().split("\n")[1:-1])
            
    # To store this dataset, choose between list-of-lists or list-of-dictionaries
    # Write your code here
    final_list = []
    for data in netflix_data:
        final_list.append(data[2])
    return final_list

netflix_data = parse_html_contents("netflix_titles.html") #Do not change these lines
top_3_titles = []
for row in netflix_data[:3]:
    top_3_titles.append(row)
top_3_titles
# Out:
# ['Norm of the North: King Sized Adventure',
#  'Jandino: Whatever it Takes',
#  'Transformers Prime']

# %%
def parse_html_contents_my_version(html_file):
    data = []
    data = open(html_file, "r", encoding = "utf-8") 
    doc = BeautifulSoup(data, "html.parser")
    table = doc.find_all("tr") 
    netflix_header = []
    headers = doc.find("tr").find_all("td") 
    for header in headers:
        netflix_header.append(header.get_text())

    netflix_data = []
    for i in range(len(table)):
        if i == 0:
            continue
        else:
            netflix_data.append(table[i].get_text().split("\n")[1:-1])
    
    netflix_dict = {}
    for movie in netflix_data:
        header_dict = {}
        header_dict['show id'] = movie[0]
        header_dict['type'] = movie[1]
        header_dict['title'] = movie[2]
        header_dict['director'] = movie[3]
        header_dict['cast'] = movie[4]
        header_dict['country'] = movie[5]
        header_dict['date_added'] = movie[6]
        header_dict['release_year'] = int(movie[7])
        header_dict['rating'] = movie[8]
        header_dict['duration'] = movie[9]
        header_dict['listed_in'] = movie[10]
        header_dict['description'] = movie[11]
        netflix_dict[movie[2]] = header_dict
    return netflix_dict

my_data = parse_html_contents_my_version("netflix_titles.html")
my_data
# Out:
# {'Norm of the North: King Sized Adventure': {'show id': '81145628',
#   'type': 'Movie',
#   'title': 'Norm of the North: King Sized Adventure',
#   'director': 'Richard Finn, Tim Maltby',
#   'cast': 'Alan Marriott, Andrew Toth, Brian Dobson, Cole Howard, Jennifer Cameron, Jonathan Holmes, Lee Tockar, Lisa Durupt, Maya Kay, Michael Dobson',
#   'country': 'United States, India, South Korea, China',
#   'date_added': 'September 9, 2019',
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '90 min',
#   'listed_in': 'Children & Family Movies, Comedies',
#   'description': 'Before planning an awesome wedding for his grandfather, a polar bear king must take back a stolen artifact from an evil archaeologist first.'},
#  'Jandino: Whatever it Takes': {'show id': '80117401',
#   'type': 'Movie',
#   'title': 'Jandino: Whatever it Takes',
#   'director': '\xa0',
#   'cast': 'Jandino Asporaat',
#   'country': 'United Kingdom',
#   'date_added': 'September 9, 2016',
#   'release_year': 2016,
#   'rating': 'TV-MA',
#   'duration': '94 min',
#   'listed_in': 'Stand-Up Comedy',
#   'description': 'Jandino Asporaat riffs on the challenges of raising kids and serenades the audience with a rousing rendition of "Sex on Fire" in his comedy show.'},
#  'Transformers Prime': {'show id': '70234439',
#   'type': 'TV Show',
#   'title': 'Transformers Prime',
#   'director': '\xa0',
#   'cast': 'Peter Cullen, Sumalee Montano, Frank Welker, Jeffrey Combs, Kevin Michael Richardson, Tania Gunadi, Josh Keaton, Steve Blum, Andy Pessoa, Ernie Hudson, Daran Norris, Will Friedle',
#   'country': 'United States',
#   'date_added': 'September 8, 2018',
#   'release_year': 2013,
#   'rating': 'TV-Y7-FV',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV",
#   'description': 'With the help of three human allies, the Autobots once again protect Earth from the onslaught of the Decepticons and their leader, Megatron.'},
#  'Transformers: Robots in Disguise': {'show id': '80058654',
#   'type': 'TV Show',
#   'title': 'Transformers: Robots in Disguise',
#   'director': '\xa0',
#   'cast': 'Will Friedle, Darren Criss, Constance Zimmer, Khary Payton, Mitchell Whitfield, Stuart Allan, Ted McGinley, Peter Cullen',
#   'country': 'United States',
#   'date_added': 'September 8, 2018',
#   'release_year': 2016,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV",
#   'description': 'When a prison ship crash unleashes hundreds of Decepticons on Earth, Bumblebee leads a new Autobot force to protect humankind.'},
#  '#realityhigh': {'show id': '80125979',
#   'type': 'Movie',
#   'title': '#realityhigh',
#   'director': 'Fernando Lebrija',
#   'cast': 'Nesta Cooper, Kate Walsh, John Michael Higgins, Keith Powers, Alicia Sanz, Jake Borelli, Kid Ink, Yousef Erakat, Rebekah Graf, Anne Winters, Peter Gilroy, Patrick Davis',
#   'country': 'United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '99 min',
#   'listed_in': 'Comedies',
#   'description': 'When nerdy high schooler Dani finally attracts the interest of her longtime crush, she lands in the cross hairs of his ex, a social media celebrity.'},
#  'Apaches': {'show id': '80163890',
#   'type': 'TV Show',
#   'title': 'Apaches',
#   'director': '\xa0',
#   'cast': 'Alberto Ammann, Eloy Azorín, Verónica Echegui, Lucía Jiménez, Claudia Traisac',
#   'country': 'Spain',
#   'date_added': 'September 8, 2017',
#   'release_year': 2016,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, International TV Shows, Spanish-Language TV Shows',
#   'description': 'A young journalist is forced into a life of crime to save his father and family in this series based on the novel by Miguel Sáez Carral.'},
#  'Automata': {'show id': '70304989',
#   'type': 'Movie',
#   'title': 'Automata',
#   'director': 'Gabe Ibáñez',
#   'cast': 'Antonio Banderas, Dylan McDermott, Melanie Griffith, Birgitte Hjort Sørensen, Robert Forster, Christa Campbell, Tim McInnerny, Andy Nyman, David Ryall',
#   'country': 'Bulgaria, United States, Spain, Canada',
#   'date_added': 'September 8, 2017',
#   'release_year': 2014,
#   'rating': 'R',
#   'duration': '110 min',
#   'listed_in': 'International Movies, Sci-Fi & Fantasy, Thrillers',
#   'description': 'In a dystopian future, an insurance adjuster for a tech company investigates a robot killed for violating protocol and discovers a global conspiracy.'},
#  'Fabrizio Copano: Solo pienso en mi': {'show id': '80164077',
#   'type': 'Movie',
#   'title': 'Fabrizio Copano: Solo pienso en mi',
#   'director': 'Rodrigo Toro, Francisco Schultz',
#   'cast': 'Fabrizio Copano',
#   'country': 'Chile',
#   'date_added': 'September 8, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '60 min',
#   'listed_in': 'Stand-Up Comedy',
#   'description': 'Fabrizio Copano takes audience participation to the next level in this stand-up set while reflecting on sperm banks, family WhatsApp groups and more.'},
#  'Fire Chasers': {'show id': '80117902',
#   'type': 'TV Show',
#   'title': 'Fire Chasers',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries, Science & Nature TV',
#   'description': "As California's 2016 fire season rages, brave backcountry firefighters race to put out the flames, protect homes and save lives in this docuseries."},
#  'Good People': {'show id': '70304990',
#   'type': 'Movie',
#   'title': 'Good People',
#   'director': 'Henrik Ruben Genz',
#   'cast': 'James Franco, Kate Hudson, Tom Wilkinson, Omar Sy, Sam Spruell, Anna Friel, Thomas Arnold, Oliver Dimsdale, Diana Hardcastle, Michael Jibson, Diarmaid Murtagh',
#   'country': 'United States, United Kingdom, Denmark, Sweden',
#   'date_added': 'September 8, 2017',
#   'release_year': 2014,
#   'rating': 'R',
#   'duration': '90 min',
#   'listed_in': 'Action & Adventure, Thrillers',
#   'description': "A struggling couple can't believe their luck when they find a stash of money in the apartment of a neighbor who was recently murdered."},
#  'Joaquín Reyes: Una y no más': {'show id': '80169755',
#   'type': 'Movie',
#   'title': 'Joaquín Reyes: Una y no más',
#   'director': 'José Miguel Contreras',
#   'cast': 'Joaquín Reyes',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '78 min',
#   'listed_in': 'Stand-Up Comedy',
#   'description': 'Comedian and celebrity impersonator Joaquín Reyes decides to be his zesty self for a night of stories about buses, bathroom habits, royalty and more.'},
#  'Kidnapping Mr. Heineken': {'show id': '70299204',
#   'type': 'Movie',
#   'title': 'Kidnapping Mr. Heineken',
#   'director': 'Daniel Alfredson',
#   'cast': 'Jim Sturgess, Sam Worthington, Ryan Kwanten, Anthony Hopkins, Mark van Eeuwen, Thomas Cocquerel, Jemima West, David Dencik',
#   'country': 'Netherlands, Belgium, United Kingdom, United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2015,
#   'rating': 'R',
#   'duration': '95 min',
#   'listed_in': 'Action & Adventure, Dramas, International Movies',
#   'description': 'When beer magnate Alfred "Freddy" Heineken is kidnapped in 1983, his abductors make the largest ransom demand in history.'},
#  'Krish Trish and Baltiboy': {'show id': '80182480',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy',
#   'director': '\xa0',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Baba Sehgal',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2009,
#   'rating': 'TV-Y7',
#   'duration': '58 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'A team of minstrels, including a monkey, cat and donkey, narrate folktales from the Indian regions of Rajasthan, Kerala and Punjab.'},
#  'Krish Trish and Baltiboy: Battle of Wits': {'show id': '80182483',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: Battle of Wits',
#   'director': 'Munjal Shroff, Tilak Shetty',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Baba Sehgal, Deepak Chachra',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2013,
#   'rating': 'TV-Y7',
#   'duration': '62 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'An artisan is cheated of his payment, a lion of his throne and a brother of his inheritance in these three stories of deception and justice.'},
#  'Krish Trish and Baltiboy: Best Friends Forever': {'show id': '80182596',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: Best Friends Forever',
#   'director': 'Munjal Shroff, Tilak Shetty',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Deepak Chachra',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2016,
#   'rating': 'TV-Y',
#   'duration': '65 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'A cat, monkey and donkey team up to narrate folktales about friendship from Northeast India, and the Indian regions of Bihar and Rajasthan.'},
#  'Krish Trish and Baltiboy: Comics of India': {'show id': '80182482',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: Comics of India',
#   'director': 'Tilak Shetty',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Baba Sehgal',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2012,
#   'rating': 'TV-Y7',
#   'duration': '61 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'In three comic-strip-style tales, a boy tries to sell wisdom, a demon is released from captivity, and a king assigns impossible tasks to his minister.'},
#  'Krish Trish and Baltiboy: Oversmartness Never Pays': {'show id': '80182597',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: Oversmartness Never Pays',
#   'director': 'Tilak Shetty',
#   'cast': 'Rishi Gambhir, Smita Malhotra, Deepak Chachra',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2017,
#   'rating': 'TV-Y7',
#   'duration': '65 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'A cat, monkey and donkey learn the consequences of cheating through stories from the Indian regions of Rajasthan, West Bengal and Maharashtra.'},
#  'Krish Trish and Baltiboy: Part II': {'show id': '80182481',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: Part II',
#   'director': '\xa0',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Baba Sehgal',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2010,
#   'rating': 'TV-Y7',
#   'duration': '58 min',
#   'listed_in': 'Children & Family Movies',
#   'description': "Animal minstrels narrate stories about a monkey's friendship with a crocodile, two monkeys' foolishness and a villager's encounter with a demon."},
#  'Krish Trish and Baltiboy: The Greatest Trick': {'show id': '80182621',
#   'type': 'Movie',
#   'title': 'Krish Trish and Baltiboy: The Greatest Trick',
#   'director': 'Munjal Shroff, Tilak Shetty',
#   'cast': 'Damandeep Singh Baggan, Smita Malhotra, Baba Sehgal',
#   'country': '\xa0',
#   'date_added': 'September 8, 2017',
#   'release_year': 2013,
#   'rating': 'TV-Y7',
#   'duration': '60 min',
#   'listed_in': 'Children & Family Movies',
#   'description': 'The consequences of trickery are explored in stories involving an inconsiderate husband, two greedy courtiers, and a kind man who loses everything.'},
#  'Love': {'show id': '80057969',
#   'type': 'Movie',
#   'title': 'Love',
#   'director': 'Gaspar Noé',
#   'cast': 'Karl Glusman, Klara Kristin, Aomi Muyock, Ugo Fox, Juan Saavedra, Gaspar Noé, Isabelle Nicou, Benoît Debie, Vincent Maraval, Déborah Révy',
#   'country': 'France, Belgium',
#   'date_added': 'September 8, 2017',
#   'release_year': 2015,
#   'rating': 'NR',
#   'duration': '135 min',
#   'listed_in': 'Cult Movies, Dramas, Independent Movies',
#   'description': 'A man in an unsatisfying marriage recalls the details of an intense past relationship with an ex-girlfriend when he gets word that she may be missing.'},
#  'Manhattan Romance': {'show id': '80060297',
#   'type': 'Movie',
#   'title': 'Manhattan Romance',
#   'director': "Tom O'Brien",
#   'cast': "Tom O'Brien, Katherine Waterston, Caitlin Fitzgerald, Gaby Hoffmann, Louis Cancelmi, Zach Grenier",
#   'country': 'United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2014,
#   'rating': 'TV-14',
#   'duration': '98 min',
#   'listed_in': 'Comedies, Independent Movies, Romantic Movies',
#   'description': 'A filmmaker working on a documentary about love in modern Manhattan becomes personally entangled in the romantic lives of his subjects.'},
#  'Moonwalkers': {'show id': '80046728',
#   'type': 'Movie',
#   'title': 'Moonwalkers',
#   'director': 'Antoine Bardou-Jacquet',
#   'cast': 'Ron Perlman, Rupert Grint, Robert Sheehan, Stephen Campbell Moore, Eric Lampaert, Kevin Bishop, Tom Audenaert, Erika Sainte',
#   'country': 'France, Belgium',
#   'date_added': 'September 8, 2017',
#   'release_year': 2015,
#   'rating': 'R',
#   'duration': '96 min',
#   'listed_in': 'Action & Adventure, Comedies, International Movies',
#   'description': 'A brain-addled war vet, a failing band manager and a Stanley Kubrick impersonator help the CIA construct an epic scam by faking the 1969 moon landing.'},
#  'Rolling Papers': {'show id': '80046727',
#   'type': 'Movie',
#   'title': 'Rolling Papers',
#   'director': 'Mitch Dickman',
#   'cast': '\xa0',
#   'country': 'United States, Uruguay',
#   'date_added': 'September 8, 2017',
#   'release_year': 2015,
#   'rating': 'TV-MA',
#   'duration': '79 min',
#   'listed_in': 'Documentaries',
#   'description': 'As the newspaper industry takes a hit, The Denver Post breaks new ground with a section dedicated to cannabis culture.'},
#  'Stonehearst Asylum': {'show id': '70304988',
#   'type': 'Movie',
#   'title': 'Stonehearst Asylum',
#   'director': 'Brad Anderson',
#   'cast': 'Kate Beckinsale, Jim Sturgess, David Thewlis, Brendan Gleeson, Ben Kingsley, Michael Caine, Jason Flemyng, Sophie Kennedy Clark, Sinéad Cusack, Edmund Kingsley',
#   'country': 'United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2014,
#   'rating': 'PG-13',
#   'duration': '113 min',
#   'listed_in': 'Horror Movies, Thrillers',
#   'description': "In 1899, a young doctor arrives at an asylum for an apprenticeship and becomes suspicious of his mentor's methods while falling for a female patient."},
#  'The Runner': {'show id': '80057700',
#   'type': 'Movie',
#   'title': 'The Runner',
#   'director': 'Austin Stark',
#   'cast': 'Nicolas Cage, Sarah Paulson, Connie Nielsen, Wendell Pierce, Bryan Batt, Peter Fonda, Dana Gourrier',
#   'country': 'United States',
#   'date_added': 'September 8, 2017',
#   'release_year': 2015,
#   'rating': 'R',
#   'duration': '90 min',
#   'listed_in': 'Dramas, Independent Movies',
#   'description': 'A New Orleans politician finds his idealistic plans for rebuilding after a toxic oil spill unraveling thanks to a sex scandal.'},
#  '6 Years': {'show id': '80045922',
#   'type': 'Movie',
#   'title': '6 Years',
#   'director': 'Hannah Fidell',
#   'cast': 'Taissa Farmiga, Ben Rosenfield, Lindsay Burdge, Joshua Leonard, Jennifer Lafleur, Peter Vack, Dana Wheeler-Nicholson, Jason Newman, Molly McMichael',
#   'country': 'United States',
#   'date_added': 'September 8, 2015',
#   'release_year': 2015,
#   'rating': 'NR',
#   'duration': '80 min',
#   'listed_in': 'Dramas, Independent Movies, Romantic Movies',
#   'description': 'As a volatile young couple who have been together for six years approach college graduation, unexpected career opportunities threaten their future.'},
#  'Castle of Stars': {'show id': '80244601',
#   'type': 'TV Show',
#   'title': 'Castle of Stars',
#   'director': '\xa0',
#   'cast': 'Chaiyapol Pupart, Jintanutda Lummakanon, Worrawech Danuwong, Ornjira Lamwilai, Yong Armchair, Keerati Mahapreukpong, Akarat Nimitchai, Kornpassorn Duaysianklao, Nattapong Chartpong',
#   'country': '\xa0',
#   'date_added': 'September 7, 2018',
#   'release_year': 2015,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Comedies',
#   'description': 'As four couples with different lifestyles go through the ebbs and flows of joy and sorrow, each must learn how to live a good life.'},
#  'City of Joy': {'show id': '80203094',
#   'type': 'Movie',
#   'title': 'City of Joy',
#   'director': 'Madeleine Gavin',
#   'cast': '\xa0',
#   'country': 'United States,',
#   'date_added': 'September 7, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '77 min',
#   'listed_in': 'Documentaries',
#   'description': "Women who've been sexually brutalized in war-torn Congo begin to heal at City of Joy, a center that helps them regain a sense of self and empowerment."},
#  'First and Last': {'show id': '80190843',
#   'type': 'TV Show',
#   'title': 'First and Last',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': '\xa0',
#   'date_added': 'September 7, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries',
#   'description': "Take an intimate look at the emotionally charged first and last days of new and soon-to-be released inmates at Georgia's Gwinnett County Jail."},
#  'Laddaland': {'show id': '70241607',
#   'type': 'Movie',
#   'title': 'Laddaland',
#   'director': 'Sopon Sukdapisit',
#   'cast': 'Saharat Sangkapreecha, Pok Piyatida Woramusik, Sutatta Udomsilp, Athipich Chutiwatkajornchai, Deuntem Salitul, Sahajak Boonthanakit',
#   'country': 'Thailand',
#   'date_added': 'September 7, 2018',
#   'release_year': 2011,
#   'rating': 'TV-MA',
#   'duration': '112 min',
#   'listed_in': 'Horror Movies, International Movies',
#   'description': 'When a family moves into an upscale housing development, they encounter a series of paranormal events that drive them to the edge of insanity.'},
#  'Next Gen': {'show id': '80988892',
#   'type': 'Movie',
#   'title': 'Next Gen',
#   'director': 'Kevin R. Adams, Joe Ksander',
#   'cast': 'John Krasinski, Charlyne Yi, Jason Sudeikis, Michael Peña, David Cross, Constance Wu',
#   'country': 'China, Canada, United States',
#   'date_added': 'September 7, 2018',
#   'release_year': 2018,
#   'rating': 'TV-PG',
#   'duration': '106 min',
#   'listed_in': 'Children & Family Movies, Comedies, Sci-Fi & Fantasy',
#   'description': 'When lonely Mai forms an unlikely bond with a top-secret robot, they embark on an intense, action-packed adventure to foil the plot of a vicious villain.'},
#  'Sierra Burgess Is A Loser': {'show id': '80239639',
#   'type': 'Movie',
#   'title': 'Sierra Burgess Is A Loser',
#   'director': 'Ian Samuels',
#   'cast': 'Shannon Purser, Kristine Froseth, RJ Cyler, Noah Centineo, Loretta Devine, Giorgia Whigham, Alice Lee, Lea Thompson, Alan Ruck, Mary Pat Gleason, Chrissy Metz',
#   'country': 'United States',
#   'date_added': 'September 7, 2018',
#   'release_year': 2018,
#   'rating': 'PG-13',
#   'duration': '106 min',
#   'listed_in': 'Comedies, Romantic Movies',
#   'description': "A wrong-number text sparks a virtual romance between a smart but unpopular teen and a sweet jock who thinks he's talking to a gorgeous cheerleader."},
#  'The Most Assassinated Woman in the World': {'show id': '80159586',
#   'type': 'Movie',
#   'title': 'The Most Assassinated Woman in the World',
#   'director': 'Franck Ribière',
#   'cast': 'Anna Mouglalis, Niels Schneider, André Wilms, Michel Fau, Sissi Duparc, Jean-Michel Balthazar, Julie Recoing, Eric Godon, Maya Coline, Constance Dollé',
#   'country': 'Belgium, United Kingdom, United States',
#   'date_added': 'September 7, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '102 min',
#   'listed_in': 'Dramas, International Movies, Thrillers',
#   'description': 'In 1930s Paris, an actress famous for her gory death scenes at the Grand Guignol Theater contends with a mysterious stalker and ghosts from her past.'},
#  'Cézanne et moi': {'show id': '80152447',
#   'type': 'Movie',
#   'title': 'Cézanne et moi',
#   'director': 'Daniele Thompson',
#   'cast': 'Guillaume Canet, Guillaume Gallienne, Alice Pol, Déborah François, Sabine Azéma, Freya Mavor, Isabelle Candelier, Laurent Stocker',
#   'country': 'Belgium, France',
#   'date_added': 'September 7, 2017',
#   'release_year': 2016,
#   'rating': 'R',
#   'duration': '114 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies',
#   'description': 'This historical drama explores the long and often volatile friendship of painter Paul Cézanne and writer Émile Zola, who first met as schoolboys.'},
#  "Archibald's Next Big Thing": {'show id': '80221550',
#   'type': 'TV Show',
#   'title': "Archibald's Next Big Thing",
#   'director': '\xa0',
#   'cast': 'Tony Hale, Rosamund Pike, Jordan Fisher, Chelsea Kane, Adam Pally, Kari Wahlgren',
#   'country': '\xa0',
#   'date_added': 'September 6, 2019',
#   'release_year': 2019,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Comedies",
#   'description': "Happy-go-lucky chicken Archibald may not remember to do his chores, but he never forgets to have fun. After all, life's an adventure!"},
#  'Article 15': {'show id': '81154455',
#   'type': 'Movie',
#   'title': 'Article 15',
#   'director': 'Anubhav Sinha',
#   'cast': 'Ayushmann Khurrana, Nassar, Manoj Pahwa, Kumud Mishra, Isha Talwar, Sayani Gupta, Mohammed Zeeshan Ayyub, Subhrajyoti Barat, Sushil Pandey, Aakash Dabhade',
#   'country': 'India',
#   'date_added': 'September 6, 2019',
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '125 min',
#   'listed_in': 'Dramas, International Movies, Thrillers',
#   'description': 'The grim realities of caste discrimination come to light as an entitled but upright city cop ventures into India’s heartland to investigate a murder.'},
#  'Care of Kancharapalem': {'show id': '81113928',
#   'type': 'Movie',
#   'title': 'Care of Kancharapalem',
#   'director': 'Maha Venkatesh',
#   'cast': 'Subba Rao Vepada, Radha Bessy, Kesava Karri, Nithyasri Goru, Karthik Rathnam, Praneetha Patnaik, Mohan Bhagath, Praveena Paruchuri',
#   'country': '\xa0',
#   'date_added': 'September 6, 2019',
#   'release_year': 2018,
#   'rating': 'TV-14',
#   'duration': '142 min',
#   'listed_in': 'Comedies, Dramas, Independent Movies',
#   'description': 'From a schoolboy’s crush to a middle-aged bachelor’s office romance, four love stories spanning age, religion and status unfold in a small Indian town.'},
#  'Ee Nagaraniki Emaindi': {'show id': '81052275',
#   'type': 'Movie',
#   'title': 'Ee Nagaraniki Emaindi',
#   'director': 'Tharun Bhascker',
#   'cast': 'Vishwaksen Naidu, Sushanth Reddy, Abhinav Gomatam, Venkatesh Kakumanu, Anisha Ambrose, Simran Choudhary',
#   'country': 'India',
#   'date_added': 'September 6, 2019',
#   'release_year': 2018,
#   'rating': 'TV-14',
#   'duration': '133 min',
#   'listed_in': 'Comedies, International Movies',
#   'description': 'In Goa and in desperate need of cash, four childhood friends get another shot at making their long-abandoned dreams of becoming filmmakers come true.'},
#  'Kill Me If You Dare': {'show id': '81132437',
#   'type': 'Movie',
#   'title': 'Kill Me If You Dare',
#   'director': 'Şenol Sönmez',
#   'cast': 'Murat Boz, Seda Bakan, Açelya Topaloğlu, Özgür Emre Yıldırım, Seda Güven, Yosi Mizrahi, Dilşad Şimşek, Ali Yoğurtçuoğlu',
#   'country': '\xa0',
#   'date_added': 'September 6, 2019',
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '100 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': 'Bogged down with money problems, a couple grows cautious of each other but hit the lottery and decide to stay together – till death do they part.'},
#  'The Spy': {'show id': '80178151',
#   'type': 'TV Show',
#   'title': 'The Spy',
#   'director': '\xa0',
#   'cast': 'Sacha Baron Cohen, Noah Emmerich, Hadar Ratzon Rotem, Alexander Siddig, Waleed Zuaiter, Nassim Lyes',
#   'country': 'France',
#   'date_added': 'September 6, 2019',
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas, TV Thrillers',
#   'description': 'In the 1960s, Israeli clerk-turned-secret agent Eli Cohen goes deep undercover inside Syria on a perilous, years-long mission to spy for Mossad.'},
#  'Hell and Back': {'show id': '80058026',
#   'type': 'Movie',
#   'title': 'Hell and Back',
#   'director': 'Tom Gianas, Ross R. Shuman',
#   'cast': 'Nick Swardson, Mila Kunis, Bob Odenkirk, T.J. Miller, Rob Riggle, Susan Sarandon, Danny McBride, Jennifer Coolidge, John Farley, Maria Bamford',
#   'country': 'United States',
#   'date_added': 'September 6, 2018',
#   'release_year': 2015,
#   'rating': 'R',
#   'duration': '86 min',
#   'listed_in': 'Action & Adventure, Comedies, Independent Movies',
#   'description': 'When best friends break a blood oath, one of them is cast away to hell, and the other two must save him from the misfits of the underworld.'},
#  'PK': {'show id': '70303496',
#   'type': 'Movie',
#   'title': 'PK',
#   'director': 'Rajkumar Hirani',
#   'cast': 'Aamir Khan, Anuskha Sharma, Sanjay Dutt, Saurabh Shukla, Parikshat Sahni, Sushant Singh Rajput, Boman Irani, Rukhsar',
#   'country': 'India',
#   'date_added': 'September 6, 2018',
#   'release_year': 2014,
#   'rating': 'TV-14',
#   'duration': '146 min',
#   'listed_in': 'Comedies, Dramas, International Movies',
#   'description': 'Aamir Khan teams with director Rajkumar Hirani to play a social crusader in a political satire on the state of corruption in India.'},
#  'Hard Tide': {'show id': '80162141',
#   'type': 'Movie',
#   'title': 'Hard Tide',
#   'director': 'Robert Osman, Nathanael Wiseman',
#   'cast': 'Nathanael Wiseman, Mem Ferda, Alexandra Newick, Oliver Stark, Kat Gellin, Andy Lucas, Ralph Brown, Beverly Hills',
#   'country': 'United Kingdom',
#   'date_added': 'September 6, 2017',
#   'release_year': 2015,
#   'rating': 'TV-MA',
#   'duration': '79 min',
#   'listed_in': 'Dramas, Independent Movies',
#   'description': "A drug dealer who's been emulating his father's successful criminal career is forced to go on the run with a young girl in this fact-based thriller."},
#  'Elstree 1976': {'show id': '80095641',
#   'type': 'Movie',
#   'title': 'Elstree 1976',
#   'director': 'Jon Spira',
#   'cast': 'Paul Blake, Jeremy Bulloch, John Chapman, Anthony Forrest, Laurie Goode, Garrick Hagon, Derek Lyons, Angus MacInnes, David Prowse, Pam Rose',
#   'country': 'United Kingdom',
#   'date_added': 'September 6, 2016',
#   'release_year': 2015,
#   'rating': 'TV-PG',
#   'duration': '102 min',
#   'listed_in': 'Documentaries',
#   'description': 'Then and now footage of bit players who appeared in "Star Wars" tells the story of how the film and its legions of fans changed their lives forever.'},
#  'American Factory: A Conversation with the Obamas': {'show id': '81176188',
#   'type': 'Movie',
#   'title': 'American Factory: A Conversation with the Obamas',
#   'director': '\xa0',
#   'cast': 'President Barack Obama, Michelle Obama, Julia Reichert, Steven Bognar',
#   'country': '\xa0',
#   'date_added': 'September 5, 2019',
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '10 min',
#   'listed_in': 'Documentaries',
#   'description': 'Barack and Michelle Obama talk with directors Steven Bognar and Julia Reichert about the documentary and the importance of storytelling.'},
#  'ATM': {'show id': '80159880',
#   'type': 'Movie',
#   'title': 'ATM',
#   'director': 'Mez Tharatorn',
#   'cast': 'Chantavit Dhanasevi, Preechaya Pongthananikorn, Chaleumpol Tikumpornteerawong, Thawat Pornrattanaprasert, Sananthachat Thanapatpisal, Pongkool Suebsung, Puttachat Pongsuchat, Gornpop Janjaroen, Yanee Tramoth, Pongsatorn Jongwilak',
#   'country': 'United States, Canada',
#   'date_added': 'September 5, 2018',
#   'release_year': 2012,
#   'rating': 'TV-14',
#   'duration': '122 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': 'When a broken ATM dishes out a fortune, a couple who works at the bank vies to see who can recover the most cash – and the loser must find a new job.'},
#  'Bangkok Traffic (Love) Story': {'show id': '81016044',
#   'type': 'Movie',
#   'title': 'Bangkok Traffic (Love) Story',
#   'director': 'Adisorn Tresirikasem',
#   'cast': 'Theeradej Wongpuapan, Sirin Horwang, Ungsumalynn Sirapatsakmetha, Panissara Phimpru, Taksaorn Paksukcharern, Charlie Trairat, Kazuki Yano',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2009,
#   'rating': 'TV-14',
#   'duration': '126 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': 'After an encounter with an engineer working the night shift for the city train, a 30-year-old woman struggles against all odds to pursue true love.'},
#  'I Fine... Thank You... Love You': {'show id': '80158838',
#   'type': 'Movie',
#   'title': 'I Fine... Thank You... Love You',
#   'director': 'Mez Tharatorn',
#   'cast': 'Preechaya Pongthananikorn, Sunny Suwanmethanont, Sora Aoi, Puttachat Pongsuchat, Popetorn Soonthornyanakij',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2014,
#   'rating': 'TV-14',
#   'duration': '116 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': "Desperate to go to the U.S. to win back his girlfriend, Yim hires a tutor to teach him English. But things don't go according to plan."},
#  'One Day': {'show id': '81016045',
#   'type': 'Movie',
#   'title': 'One Day',
#   'director': 'Banjong Pisanthanakun',
#   'cast': 'Chantavit Dhanasevi, Nittha Jirayungyurn, Theerapat Sajakul, Prim Bulakul, Kris Srepoomseth, Somyos Matures, Sutthatip Wutichaipradit, Rermthon Kemapech, Kaz Sawamura',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2016,
#   'rating': 'TV-PG',
#   'duration': '135 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies',
#   'description': 'When his colleague (and crush) temporarily loses her memory, an overlooked geek seizes the chance to make an impression before she remembers again.'},
#  'Phobia 2': {'show id': '70142798',
#   'type': 'Movie',
#   'title': 'Phobia 2',
#   'director': 'Banjong Pisanthanakun, Paween Purikitpanya, Songyos Sugmakanan, Parkpoom Wongpoom, Visute Poolvoralaks',
#   'cast': 'Jirayu La-ongmanee, Charlie Trairat, Worrawech Danuwong, Marsha Wattanapanich, Nicole Theriault, Chumphorn Thepphithak, Gacha Plienwithi, Suteerush Channukool, Peeratchai Roompol, Nattapong Chartpong',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2009,
#   'rating': 'TV-MA',
#   'duration': '125 min',
#   'listed_in': 'Horror Movies, International Movies',
#   'description': 'From disfiguring punishments to festering souls, Thai horror masters present five supernatural tales of karma in this sequel to the 4bia anthology.'},
#  'Shutter': {'show id': '70062814',
#   'type': 'Movie',
#   'title': 'Shutter',
#   'director': 'Banjong Pisanthanakun, Parkpoom Wongpoom',
#   'cast': 'Ananda Everingham, Natthaweeranuch Thongmee, Achita Sikamana, Unnop Chanpaibool, Titikarn Tongprasearth, Sivagorn Muttamara, Chachchaya Chalemphol, Kachormsak Naruepatr',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2004,
#   'rating': 'TV-MA',
#   'duration': '96 min',
#   'listed_in': 'Horror Movies, International Movies',
#   'description': 'After killing a young girl in a hit-and-run accident, a couple is haunted by more than just the memory of their deadly choice.'},
#  'Suckseed': {'show id': '80158839',
#   'type': 'Movie',
#   'title': 'Suckseed',
#   'director': 'Chayanop Boonprakob',
#   'cast': 'Jirayu La-ongmanee, Pachara Chirathivat, Nattasha Nauljam, Thawat Pornrattanaprasert',
#   'country': 'Thailand',
#   'date_added': 'September 5, 2018',
#   'release_year': 2011,
#   'rating': 'TV-MA',
#   'duration': '130 min',
#   'listed_in': 'Comedies, International Movies',
#   'description': 'When his boyhood crush Ern returns, Ped forms a band with his friend to impress her. Romantic rivalries bloom after the talented Ern joins the group.'},
#  'Carrie Pilby': {'show id': '80147760',
#   'type': 'Movie',
#   'title': 'Carrie Pilby',
#   'director': 'Susan Johnson',
#   'cast': "Bel Powley, Nathan Lane, Vanessa Bayer, Gabriel Byrne, Jason Ritter, Colin O'Donoghue, William Moseley, Desmin Borges",
#   'country': 'United States',
#   'date_added': 'September 5, 2017',
#   'release_year': 2016,
#   'rating': 'TV-14',
#   'duration': '98 min',
#   'listed_in': 'Comedies, Dramas',
#   'description': 'A socially awkward 19-year-old genius makes big plans to step out of her shell and make a friend, get a job and – maybe – even go on a date.'},
#  'Marc Maron: Too Real': {'show id': '80177405',
#   'type': 'Movie',
#   'title': 'Marc Maron: Too Real',
#   'director': 'Lynn Shelton',
#   'cast': 'Marc Maron',
#   'country': 'United States',
#   'date_added': 'September 5, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '70 min',
#   'listed_in': 'Stand-Up Comedy',
#   'description': 'Battle-scarred stand-up comedian Marc Maron unleashes a storm of ideas about meditation, mortality, documentary films and our weird modern world.'},
#  'No Tomorrow': {'show id': '80113482',
#   'type': 'TV Show',
#   'title': 'No Tomorrow',
#   'director': '\xa0',
#   'cast': 'Joshua Sasse, Tori Anderson, Jonathan Langdon, Sarayu Blue, Jesse Rath, Amy Pietz',
#   'country': 'United States',
#   'date_added': 'September 5, 2017',
#   'release_year': 2016,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Romantic TV Shows, TV Comedies, TV Dramas',
#   'description': 'Her straitjacketed life turned topsy-turvy by hunky Xavier, Evie discovers a new freedom – even though her man just might be an end-of-days crackpot.'},
#  'Saawan': {'show id': '81160036',
#   'type': 'Movie',
#   'title': 'Saawan',
#   'director': 'Farhan Alam',
#   'cast': 'Karam Hussain, Arif Bahlim, Najiba Faiz, Saleem Mairaj, Imran Aslam, Daniyal Yousuf, Sohail Malik, Ali Hafiz',
#   'country': 'Pakistan',
#   'date_added': 'September 4, 2019',
#   'release_year': 2016,
#   'rating': 'TV-14',
#   'duration': '128 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies',
#   'description': 'Outcast from society and left to die in the wilderness, a young boy with polio embarks on a journey to connect with his mother. Based on a true story.'},
#  'The Heretics': {'show id': '81173255',
#   'type': 'Movie',
#   'title': 'The Heretics',
#   'director': 'Chad Archibald',
#   'cast': 'Nina Kiri, Ry Barrett, Jorja Cadence, Will King, Nina Richmond',
#   'country': 'Canada',
#   'date_added': 'September 4, 2019',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '88 min',
#   'listed_in': 'Horror Movies',
#   'description': 'A withdrawn young woman hunted by a malicious cult is abducted by a brooding stranger and undergoes a bizarre transformation.'},
#  'The World We Make': {'show id': '81078908',
#   'type': 'Movie',
#   'title': 'The World We Make',
#   'director': 'Brian Baugh',
#   'cast': 'Caleb Castille, Rose Reid, Kevin Sizemore, Gregory Alan Williams',
#   'country': 'United States',
#   'date_added': 'September 4, 2019',
#   'release_year': 2019,
#   'rating': 'PG',
#   'duration': '108 min',
#   'listed_in': 'Dramas, Romantic Movies',
#   'description': 'A teenage equestrian and a local football player for each other, but simmering racism in their small town puts their relationship to the test.'},
#  'Watchman': {'show id': '81155784',
#   'type': 'Movie',
#   'title': 'Watchman',
#   'director': 'A. L. Vijay',
#   'cast': 'G.V. Prakash Kumar, Samyuktha Hegde, Suman, Raj Arjun, Yogi Babu, Munishkanth',
#   'country': 'India',
#   'date_added': 'September 4, 2019',
#   'release_year': 2019,
#   'rating': 'TV-14',
#   'duration': '93 min',
#   'listed_in': 'Comedies, Dramas, International Movies',
#   'description': 'Rushing to pay off a loan shark, a young man breaks into a bungalow to steal the cash, unprepared for the dog standing guard – or the trouble inside.'},
#  'Black Panther': {'show id': '80201906',
#   'type': 'Movie',
#   'title': 'Black Panther',
#   'director': 'Ryan Coogler',
#   'cast': "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai Gurira, Martin Freeman, Daniel Kaluuya, Letitia Wright, Winston Duke, Sterling K. Brown, Angela Bassett, Forest Whitaker, Andy Serkis, Florence Kasumba, John Kani, David S. Lee, Stan Lee",
#   'country': 'United States',
#   'date_added': 'September 4, 2018',
#   'release_year': 2018,
#   'rating': 'PG-13',
#   'duration': '135 min',
#   'listed_in': 'Action & Adventure, Sci-Fi & Fantasy',
#   'description': "T'Challa, the superpowered new leader of the hidden, highly advanced African nation of Wakanda, strives to protect his home from enemies old and new."},
#  'Man Up': {'show id': '80052612',
#   'type': 'Movie',
#   'title': 'Man Up',
#   'director': 'Ben Palmer',
#   'cast': 'Lake Bell, Simon Pegg, Ophelia Lovibond, Olivia Williams, Rory Kinnear, Henry Lloyd-Hughes, Ken Stott, Sharon Horgan, Harriet Walter, Stephen Campbell Moore, Dean-Charles Chapman, Phoebe Waller-Bridge',
#   'country': 'United Kingdom, France',
#   'date_added': 'September 4, 2018',
#   'release_year': 2015,
#   'rating': 'R',
#   'duration': '88 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': 'A single woman seizes an opportunity when, while standing under a train station clock, she meets a stranger who mistakes her for his blind date.'},
#  'Frequency': {'show id': '80113641',
#   'type': 'TV Show',
#   'title': 'Frequency',
#   'director': '\xa0',
#   'cast': 'Peyton List, Riley Smith, Mekhi Phifer, Devin Kelley, Lenny Jacobson, Daniel Bonjour, Anthony Ruivivar',
#   'country': 'United States',
#   'date_added': 'September 4, 2017',
#   'release_year': 2016,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Crime TV Shows, TV Dramas, TV Mysteries',
#   'description': 'A detective seizes a precious opportunity to change the past when she finds she can communicate with her deceased, estranged father via a time warp.'},
#  'Mo Gilligan: Momentum': {'show id': '81054495',
#   'type': 'Movie',
#   'title': 'Mo Gilligan: Momentum',
#   'director': 'Chris Howe',
#   'cast': 'Mo Gilligan',
#   'country': 'United Kingdom',
#   'date_added': 'September 30, 2019',
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '64 min',
#   'listed_in': 'Stand-Up Comedy',
#   'description': 'Comedian Mo Gilligan blends smooth moves and sharp humor as he riffs on humble beginnings, family dynamics and the complex art of dancing in the club.'},
#  'Adam Ruins Everything': {'show id': '80996949',
#   'type': 'TV Show',
#   'title': 'Adam Ruins Everything',
#   'director': '\xa0',
#   'cast': 'Adam Conover, Adam Lustick, Emily Axford',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2018,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'TV Comedies',
#   'description': 'Education can be fun – and funny. Comedian Adam Conover bursts misconceptions, deconstructs topics and leaves with positive takeaways.'},
#  'Ben 10': {'show id': '80239337',
#   'type': 'TV Show',
#   'title': 'Ben 10',
#   'director': '\xa0',
#   'cast': 'Tara Strong, Montse Hernandez, David Kaye, Roger Craig Smith, Todd Haberkorn, Dwight Schultz, Daryl Sabara',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2016,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV",
#   'description': "Ben can transform into ten types of aliens. He'll try 'em all while adventuring across the country with his cousin Gwen and Grandpa Max."},
#  'Big Miracle': {'show id': '70212504',
#   'type': 'Movie',
#   'title': 'Big Miracle',
#   'director': 'Ken Kwapis',
#   'cast': 'Drew Barrymore, John Krasinski, Kristen Bell, Dermot Mulroney, Tim Blake Nelson, Vinessa Shaw, Ted Danson, Stephen Root, Rob Riggle, Michael Gaston',
#   'country': 'United States, United Kingdom',
#   'date_added': 'September 30, 2018',
#   'release_year': 2012,
#   'rating': 'PG',
#   'duration': '107 min',
#   'listed_in': 'Children & Family Movies, Dramas',
#   'description': 'After a reporter writes about whales trapped in the Arctic Circle, the U.S. and U.S.S.R. team up to rescue them in this tale inspired by true events.'},
#  'Christiane Amanpour: Sex & Love Around the World': {'show id': '81011682',
#   'type': 'TV Show',
#   'title': 'Christiane Amanpour: Sex & Love Around the World',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries',
#   'description': "A contextual, acculturated dive into how adults in six, big global cities celebrate love and accentuate sex. CNN's Christiane Amanpour reports."},
#  'The Eighties': {'show id': '80128317',
#   'type': 'TV Show',
#   'title': 'The Eighties',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2016,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries',
#   'description': 'This nostalgic documentary series relives the 1980s from a variety of angles, exploring its impact on the politics, technology and culture of today.'},
#  'The Nineties': {'show id': '81027384',
#   'type': 'TV Show',
#   'title': 'The Nineties',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries',
#   'description': 'This U.S.-focused series dives into the cultural and political changes that swept the last decade of the 20th century. Executive produced by Tom Hanks.'},
#  'The Seventies': {'show id': '80030186',
#   'type': 'TV Show',
#   'title': 'The Seventies',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2015,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'Docuseries',
#   'description': 'This series examines 1970s America, focusing on the major political and historical landmarks of the decade and the cultural response to those events.'},
#  'We Bare Bears': {'show id': '80116921',
#   'type': 'TV Show',
#   'title': 'We Bare Bears',
#   'director': '\xa0',
#   'cast': 'Eric Edelstein, Demetri Martin, Bobby Moynihan',
#   'country': 'United States',
#   'date_added': 'September 30, 2018',
#   'release_year': 2017,
#   'rating': 'TV-Y7',
#   'duration': '1 Season',
#   'listed_in': "Kids' TV, TV Comedies",
#   'description': 'Grizzly, Panda and Ice Bear are three adopted bear brothers struggling against their animal instincts to fit into the civilized, modern human world.'},
#  'The Mayor': {'show id': '80187061',
#   'type': 'Movie',
#   'title': 'The Mayor',
#   'director': 'Park In-je',
#   'cast': 'Min-sik Choi, Do-won Kwak, Eun-kyung Shim, So-ri Moon, Mi-ran Ra, Hye-young Ryu, Ki Hong Lee, Sun-gyu Jin, Joo-yeon Lee, Byeong-eun Park',
#   'country': 'South Korea',
#   'date_added': 'September 30, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '130 min',
#   'listed_in': 'Dramas, International Movies',
#   'description': 'With the presidency in mind, the incumbent mayor of Seoul runs for an unprecedented third term – and will stop at nothing to keep his secrets hidden.'},
#  'The Royal House of Windsor': {'show id': '80181555',
#   'type': 'TV Show',
#   'title': 'The Royal House of Windsor',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United Kingdom',
#   'date_added': 'September 30, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Docuseries, International TV Shows',
#   'description': 'Drawing on newly available info, this show traces how the British royal family has survived the last 100 years of power struggles, politics and more.'},
#  'Amanda Knox': {'show id': '80081155',
#   'type': 'Movie',
#   'title': 'Amanda Knox',
#   'director': 'Rod Blackhurst, Brian McGinn',
#   'cast': '\xa0',
#   'country': 'Denmark, United States',
#   'date_added': 'September 30, 2016',
#   'release_year': 2016,
#   'rating': 'TV-MA',
#   'duration': '92 min',
#   'listed_in': 'Documentaries',
#   'description': 'She was twice convicted and acquitted of murder. Amanda Knox and the people closest to her case speak out in this illuminating documentary.'},
#  'Lovesick': {'show id': '80184358',
#   'type': 'TV Show',
#   'title': 'Lovesick',
#   'director': '\xa0',
#   'cast': 'Kongyingyong Chonlathorn, Phumphothingam Nawat, Luangsodsai Anupart, Nuchanart Veerakaarn, Chindavanich Primrose, Charnmanoon Pannin, Nungira Hanwutinanon, Ausavaterakul Ausavapat, Sirikiet Saejea, Nontapan Chuenwarin',
#   'country': '\xa0',
#   'date_added': 'September 3, 2018',
#   'release_year': 2014,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Romantic TV Shows, TV Dramas',
#   'description': 'Love and academics get complicated at an all-male college that happens to be located next to an all-female high school.'},
#  'The Debt Collector': {'show id': '80198585',
#   'type': 'Movie',
#   'title': 'The Debt Collector',
#   'director': 'Jesse V. Johnson',
#   'cast': 'Scott Adkins, Louis Mandylor, Vladimir Kulich, Michael Paré, Rachel Brann, Selina Lo, Tony Todd',
#   'country': 'United Kingdom, United States',
#   'date_added': 'September 3, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '96 min',
#   'listed_in': 'Action & Adventure',
#   'description': 'A broke martial arts instructor takes a side gig with a mobster, who pairs him with a veteran thug for a weekend of fisticuffs-fueled debt collection.'},
#  'Act of Vengeance': {'show id': '70233894',
#   'type': 'Movie',
#   'title': 'Act of Vengeance',
#   'director': 'Mahsun Kırmızıgül',
#   'cast': 'Haluk Bilginer, Mahsun Kırmızıgül, Mustafa Sandal, Gina Gershon, Robert Patrick, Danny Glover, Engin Altan Düzyatan, Scott William Winters, Sharrieff Pugh',
#   'country': 'Turkey, United States',
#   'date_added': 'September 29, 2018',
#   'release_year': 2010,
#   'rating': 'NR',
#   'duration': '112 min',
#   'listed_in': 'Action & Adventure, International Movies',
#   'description': 'Two Turkish agents are sent to New York City on a mission to capture a notorious terrorist known only as "Dejjal" (Arabic for Antichrist).'},
#  'Paradise Lost': {'show id': '81011955',
#   'type': 'Movie',
#   'title': 'Paradise Lost',
#   'director': 'Monique Gardenberg',
#   'cast': 'Júlio Andrade, Lee Taylor, Hermila Guedes, Julia Konrad, Erasmo Carlos, Marjorie Estiano, Seu Jorge, Jaloo, Felipe Abib, Humberto Carrão, Malu Galli',
#   'country': 'Brazil',
#   'date_added': 'September 29, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '111 min',
#   'listed_in': 'Dramas, Independent Movies, International Movies',
#   'description': 'A cop moonlights as the bodyguard for a young drag queen at a nightclub, and grows closer to the family of misfit singers that perform there.'},
#  "Gerald's Game": {'show id': '80128722',
#   'type': 'Movie',
#   'title': "Gerald's Game",
#   'director': 'Mike Flanagan',
#   'cast': 'Carla Gugino, Bruce Greenwood, Henry Thomas, Carel Struycken, Chiara Aurelia',
#   'country': 'United States',
#   'date_added': 'September 29, 2017',
#   'release_year': 2017,
#   'rating': 'TV-MA',
#   'duration': '103 min',
#   'listed_in': 'Horror Movies, Thrillers',
#   'description': "When her husband's sex game goes wrong, Jessie – handcuffed to a bed in a remote lake house – faces warped visions, dark secrets and a dire choice."},
#  'Long Shot': {'show id': '80182115',
#   'type': 'Movie',
#   'title': 'Long Shot',
#   'director': 'Jacob LaMendola',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 29, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '40 min',
#   'listed_in': 'Documentaries',
#   'description': "When Juan Catalan is arrested for a murder he didn't commit, he builds his case for innocence around raw footage from a popular TV show. A documentary."},
#  'Mak Cun': {'show id': '80163293',
#   'type': 'TV Show',
#   'title': 'Mak Cun',
#   'director': '\xa0',
#   'cast': 'Erma Fatima, Rahim Razali, Umie Aida, Nora Danish',
#   'country': '\xa0',
#   'date_added': 'September 29, 2017',
#   'release_year': 2015,
#   'rating': 'TV-PG',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Comedies, TV Dramas',
#   'description': 'A woman with an entrepreneurial spirit takes life into her own hands by starting a beauty cream business that inspires other women to take chances.'},
#  'Our Souls at Night': {'show id': '80104068',
#   'type': 'Movie',
#   'title': 'Our Souls at Night',
#   'director': 'Ritesh Batra',
#   'cast': 'Robert Redford, Jane Fonda, Bruce Dern, Matthias Schoenaerts, Iain Armitage, Judy Greer, Phyllis Somerville',
#   'country': 'United States',
#   'date_added': 'September 29, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '103 min',
#   'listed_in': 'Dramas, Romantic Movies',
#   'description': 'After widowed neighbors Addie and Louis begin sleeping in bed together platonically to alleviate their loneliness, a real romance begins to blossom.'},
#  'Out of Thin Air': {'show id': '80119349',
#   'type': 'Movie',
#   'title': 'Out of Thin Air',
#   'director': 'Dylan Howitt',
#   'cast': '\xa0',
#   'country': '\xa0',
#   'date_added': 'September 29, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '85 min',
#   'listed_in': 'Documentaries, International Movies',
#   'description': 'Picking up 40 years after six were convicted for two strange murders in Iceland, this chilling documentary proves confessions can’t always be trusted.'},
#  "Paul Hollywood's Big Continental Road Trip": {'show id': '80199032',
#   'type': 'TV Show',
#   'title': "Paul Hollywood's Big Continental Road Trip",
#   'director': '\xa0',
#   'cast': 'Paul Hollywood',
#   'country': 'United Kingdom',
#   'date_added': 'September 29, 2017',
#   'release_year': 2017,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'British TV Shows, Docuseries, International TV Shows',
#   'description': 'Gear up for a fast-paced journey as celebrity chef and avid auto enthusiast Paul Hollywood takes in the cars and culture of France, Italy and Germany.'},
#  'Satu Hari': {'show id': '80180449',
#   'type': 'TV Show',
#   'title': 'Satu Hari',
#   'director': '\xa0',
#   'cast': 'Sara Ali, Remy Ishak, Rita Rudaini, Mirza Salihovic, Hafizul Kamal, Miller Khan',
#   'country': '\xa0',
#   'date_added': 'September 29, 2017',
#   'release_year': 2014,
#   'rating': 'TV-14',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Dramas',
#   'description': "A man haunted by his wife's affair moves to Sarajevo and starts to love again, until fate forces him to choose between his new life and old loyalty."},
#  'Monster High: Boo York, Boo York': {'show id': '80019931',
#   'type': 'Movie',
#   'title': 'Monster High: Boo York, Boo York',
#   'director': 'William Lau',
#   'cast': 'Karen Strassman, Celeste Henderson, Wendee Lee, TJ Smith, America Young, Rachel Staman, Laura Bailey',
#   'country': 'United States',
#   'date_added': 'September 29, 2015',
#   'release_year': 2015,
#   'rating': 'TV-Y7',
#   'duration': '72 min',
#   'listed_in': 'Children & Family Movies, Music & Musicals',
#   'description': 'Cleo is invited to a gala in the big city celebrating a magical comet and brings her best friends along. But the sinister Nefera has other plans.'},
#  'Cultivating the Seas: History and Future of the Full-Cycle Cultured Kindai Tuna': {'show id': '81053893',
#   'type': 'Movie',
#   'title': 'Cultivating the Seas: History and Future of the Full-Cycle Cultured Kindai Tuna',
#   'director': 'Mana Yasuda',
#   'cast': '\xa0',
#   'country': '\xa0',
#   'date_added': 'September 28, 2019',
#   'release_year': 2019,
#   'rating': 'TV-G',
#   'duration': '45 min',
#   'listed_in': 'Documentaries, International Movies',
#   'description': 'An in-depth look at the full-cycle breeding program for bluefin Kindai tuna pioneered by Kinki University’s Aqua Culture Research Institute.'},
#  'Domino': {'show id': '80200087',
#   'type': 'Movie',
#   'title': 'Domino',
#   'director': 'Brian De Palma',
#   'cast': 'Nikolaj Coster-Waldau, Carice van Houten, Eriq Ebouaney, Guy Pearce, Mohammed Azaay, Søren Malling, Paprika Steen, Helena Kaittani',
#   'country': 'Denmark, France, Italy, Belgium, Netherlands',
#   'date_added': 'September 28, 2019',
#   'release_year': 2019,
#   'rating': 'R',
#   'duration': '89 min',
#   'listed_in': 'International Movies, Thrillers',
#   'description': 'A Copenhagen police officer hunts for the man who attacked his partner, only to stumble into a high-stakes game of espionage.'},
#  'TUNA GIRL': {'show id': '81053892',
#   'type': 'Movie',
#   'title': 'TUNA GIRL',
#   'director': 'Mana Yasuda',
#   'cast': 'Fuka Koshiba, Tom Fujita, Hidetoshi Hoshida, Hiroto Kanai, Ryosuke Yusa, Shuri Tanaka, Chal Inoue, Takashi Taniguchi, Takeshi Masu',
#   'country': '\xa0',
#   'date_added': 'September 28, 2019',
#   'release_year': 2019,
#   'rating': 'TV-PG',
#   'duration': '90 min',
#   'listed_in': 'Dramas, International Movies',
#   'description': "A clumsy but cheerful fisheries student struggles to find her place at a research institute renowned for its tuna cultivation. The work isn't easy."},
#  '5CM': {'show id': '81002850',
#   'type': 'Movie',
#   'title': '5CM',
#   'director': 'Rizal Mantovani',
#   'cast': 'Herjunot Ali, Raline Shah, Fedi Nuril, Pevita Pearce, Saykoji, Denny Sumargo, Didi Petet, Firrina Sinatrya',
#   'country': 'Indonesia',
#   'date_added': 'September 28, 2018',
#   'release_year': 2012,
#   'rating': 'TV-14',
#   'duration': '126 min',
#   'listed_in': 'Dramas, International Movies',
#   'description': 'Five friends embark on a mission to climb the highest peak in Java, overcoming obstacles on the way and discovering the true meaning of friendship.'},
#  'Animal World': {'show id': '81004470',
#   'type': 'Movie',
#   'title': 'Animal World',
#   'director': 'Han Yan',
#   'cast': 'Li Yi Feng, Zhou Dongyu, Michael Douglas, Bingkun Cao, Ge Wang, Keanu Chi, Zhang Jungyi, Yijuan Li, Su Ke',
#   'country': 'China',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '130 min',
#   'listed_in': 'Action & Adventure, International Movies, Sci-Fi & Fantasy',
#   'description': "An unlucky, debt-ridden teen resorts to his math skills when he's forced into a deadly tournament of rock-paper-scissors run by a diabolical host."},
#  'Hold the Dark': {'show id': '80157072',
#   'type': 'Movie',
#   'title': 'Hold the Dark',
#   'director': 'Jeremy Saulnier',
#   'cast': 'Jeffrey Wright, Alexander Skarsgård, James Badge Dale, Riley Keough, Julian Black Antelope, Tantoo Cardinal, Macon Blair, Jonathan Whitesell, Peter McRobbie',
#   'country': 'United States',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '126 min',
#   'listed_in': 'Action & Adventure, Dramas',
#   'description': 'In the grim Alaskan winter, a naturalist hunts for wolves blamed for killing a local boy, but he soon finds himself swept into a chilling mystery.'},
#  'Lessons from a School Shooting: Notes from Dunblane': {'show id': '81001809',
#   'type': 'Movie',
#   'title': 'Lessons from a School Shooting: Notes from Dunblane',
#   'director': 'Kim A. Snyder',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-PG',
#   'duration': '24 min',
#   'listed_in': 'Documentaries',
#   'description': 'Two priests – one from Dunblane, Scotland, the other from Newtown, Connecticut – bond over school tragedies that occurred 16 years apart.'},
#  'Made in Mexico': {'show id': '80201933',
#   'type': 'TV Show',
#   'title': 'Made in Mexico',
#   'director': '\xa0',
#   'cast': '\xa0',
#   'country': 'United States',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, Reality TV, Spanish-Language TV Shows',
#   'description': 'These Mexico City socialites may lead opulent lives, but a peek behind the curtain reveals a tangled web of intrigue, envy and personal struggles.'},
#  'Single': {'show id': '81002864',
#   'type': 'Movie',
#   'title': 'Single',
#   'director': 'Raditya Dika',
#   'cast': 'Raditya Dika, Annisa Rawles, Chandra Liow, Pandji Pragiwaksono, Babe Cabita, Elvira Devinamira, Tinna Harahap, Pevita Pearce, Rinna Hassim, Dede Yusuf, Dewi Hughes',
#   'country': 'Indonesia',
#   'date_added': 'September 28, 2018',
#   'release_year': 2015,
#   'rating': 'TV-PG',
#   'duration': '127 min',
#   'listed_in': 'Comedies, International Movies, Romantic Movies',
#   'description': 'Unemployed and immature, a somewhat pathetic bachelor sets his sights on finding a date for the wedding of his younger, more successful brother.'},
#  'The 3rd Eye': {'show id': '81016750',
#   'type': 'Movie',
#   'title': 'The 3rd Eye',
#   'director': 'Rocky Soraya',
#   'cast': 'Jessica Mila, Denny Sumargo, Citra Prima, Bianca Hello, Epy Kusnandar, Anita Hara, Derry Drajat, Voke Victoria, Shofia Shireen, Afdhal Yusman',
#   'country': 'Indonesia',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '108 min',
#   'listed_in': 'Horror Movies, International Movies',
#   'description': 'When her little sister claims she sees the dead, Alia consults a psychic, who opens her own eyes to the vengeful ghosts haunting their childhood home.'},
#  'The Sinking Of Van Der Wijck': {'show id': '81002866',
#   'type': 'Movie',
#   'title': 'The Sinking Of Van Der Wijck',
#   'director': 'Sunil Soraya',
#   'cast': 'Herjunot Ali, Pevita Pearce, Reza Rahadian, Randy Nidji, Gesya Shandy, Kevin Andrean, Arzetti Bilbina',
#   'country': 'Indonesia',
#   'date_added': 'September 28, 2018',
#   'release_year': 2013,
#   'rating': 'TV-14',
#   'duration': '163 min',
#   'listed_in': 'Dramas, International Movies, Romantic Movies',
#   'description': 'When a young man leaves home to fulfill the wishes of his late father, he meets and falls in love with a woman from a very different background.'},
#  'Two Catalonias': {'show id': '80992039',
#   'type': 'Movie',
#   'title': 'Two Catalonias',
#   'director': 'Álvaro Longoria, Gerardo Olivares',
#   'cast': '\xa0',
#   'country': 'Spain',
#   'date_added': 'September 28, 2018',
#   'release_year': 2018,
#   'rating': 'TV-MA',
#   'duration': '117 min',
#   'listed_in': 'Documentaries, International Movies',
#   'description': "Lawmakers and activists with conflicting ideologies speak about the complexities of Catalonia's politics and the fight for its independence from Spain."},
#  'Bobby Sands: 66 Days': {'show id': '80126507',
#   'type': 'Movie',
#   'title': 'Bobby Sands: 66 Days',
#   'director': 'Brendan Byrne',
#   'cast': '\xa0',
#   'country': 'Ireland, United Kingdom',
#   'date_added': 'September 28, 2017',
#   'release_year': 2016,
#   'rating': 'TV-14',
#   'duration': '106 min',
#   'listed_in': 'Documentaries',
#   'description': 'In 1981, an imprisoned Irish Republican Army soldier went on a hunger strike that galvanized his movement and made him a controversial global icon.'},
#  'Bard of Blood': {'show id': '80225885',
#   'type': 'TV Show',
#   'title': 'Bard of Blood',
#   'director': '\xa0',
#   'cast': 'Emraan Hashmi, Viineet Kumar, Sobhita Dhulipala, Jaideep Ahlawat, Kirti Kulhari, Sohum Shah, Rajit Kapoor, Danish Hussain',
#   'country': 'India',
#   'date_added': 'September 27, 2019',
#   'release_year': 2019,
#   'rating': 'TV-MA',
#   'duration': '1 Season',
#   'listed_in': 'International TV Shows, TV Action & Adventure, TV Dramas',
#   'description': 'Years after a disastrous job in Balochistan, a former Indian spy must confront his past when he returns to lead an unsanctioned hostage-rescue mission.'}}

# %% [markdown]
# ## Questions q20 to q21 address topics covered by project P8.
# ### Question 20: List the *first 10* TV shows' *titles* in the dataset.
# - There are different types of Netflix videos in this dataset, such as TV shows and movies.
# - This question asks you to list *only* first 10 *TV shows*.
# - Your cell should output a list.

# %%
# q20: List the first 10 TV shows' titles in the dataset.
tv_show_list = []
for data in my_data:
    if my_data[data]['type'] == 'TV Show':
        tv_show_list.append(data)
tv_show_list[:10]
# Out:
# ['Transformers Prime',
#  'Transformers: Robots in Disguise',
#  'Apaches',
#  'Fire Chasers',
#  'Castle of Stars',
#  'First and Last',
#  "Archibald's Next Big Thing",
#  'The Spy',
#  'No Tomorrow',
#  'Frequency']

# %% [markdown]
# ### Question 21: How many *movies* released *after 2015 (inclusive)* are in this dataset?
# - This question asks you to consider *only movies*.
# - Your cell should output an int.

# %%
# q21: How many movies released after 2015 (inclusive) are in this dataset?
movies_after_2015 = []
for data in my_data:
    if my_data[data]['type'] == 'Movie' and my_data[data]['release_year'] >= 2015:
        movies_after_2015.append(data)
len(movies_after_2015)
# Out:
# 55

# %% [markdown]
# ## Analysing the movies data in the data folder (q22, q23).
# ## Questions q22, q23 address topics covered by project P9.
#
# - The data folder consists of two things
#   1. movies.csv, which consists of the movie_id, title, and genres corresponding to the movie.
#   2. The users directory inside the data folder consists of the ratings given by 10 users in files named from 1.json to 10.json.
#      - The first attribute in the file refers to the movie_id, and second attribute refers to the rating given by that user to that movie.

# %% [markdown]
# ### Question 22: What is the *average rating* for the movie with id *34*?
# - Combine all the json files in the users directory inside the data directory and calculate the average rating for the movie ids present in these files.
# - Remember a particular movie_id can be part of multiple files!
# - You can read the json files one by one and add the entries to a dictionary:
#   - with the key as the movie_id (in integer format) and as the value you can maintan a list of ratings
#   - each rating value stored as a float
# - You can now iterate over the created dictionary and calculate the average rating corresponding to each movie_id
# - Your cell should output a float

# %%
directory_path = os.path.join("data", "users")
def get_names(directory):
    file_list = os.listdir(directory)
    return sorted(file_list)

# %%
def read_json(json_filename):
    f = open(os.path.join("data", json_filename), encoding="utf-8")
    string = f.read()
    json_str = json.loads(string)
    f.close()
    
    return json_str

# %%
read_json(os.path.join('users', '1.json'))
# Out:
# {'1': '4.0',
#  '3': '4.0',
#  '6': '4.0',
#  '47': '5.0',
#  '50': '5.0',
#  '70': '3.0',
#  '101': '5.0',
#  '110': '4.0',
#  '151': '5.0',
#  '157': '5.0',
#  '163': '5.0',
#  '216': '5.0',
#  '223': '3.0',
#  '231': '5.0',
#  '235': '4.0',
#  '260': '5.0',
#  '296': '3.0',
#  '316': '3.0',
#  '333': '5.0',
#  '349': '4.0',
#  '356': '4.0',
#  '362': '5.0',
#  '367': '4.0',
#  '423': '3.0',
#  '441': '4.0',
#  '457': '5.0',
#  '480': '4.0',
#  '500': '3.0',
#  '527': '5.0',
#  '543': '4.0',
#  '552': '4.0',
#  '553': '5.0',
#  '590': '4.0',
#  '592': '4.0',
#  '593': '4.0',
#  '596': '5.0',
#  '608': '5.0',
#  '648': '3.0',
#  '661': '5.0',
#  '673': '3.0',
#  '733': '4.0',
#  '736': '3.0',
#  '780': '3.0',
#  '804': '4.0',
#  '919': '5.0',
#  '923': '5.0',
#  '940': '5.0',
#  '943': '4.0',
#  '954': '5.0',
#  '1009': '3.0',
#  '1023': '5.0',
#  '1024': '5.0',
#  '1025': '5.0',
#  '1029': '5.0',
#  '1030': '3.0',
#  '1031': '5.0',
#  '1032': '5.0',
#  '1042': '4.0',
#  '1049': '5.0',
#  '1060': '4.0',
#  '1073': '5.0',
#  '1080': '5.0',
#  '1089': '5.0',
#  '1090': '4.0',
#  '1092': '5.0',
#  '1097': '5.0',
#  '1127': '4.0',
#  '1136': '5.0',
#  '1196': '5.0',
#  '1197': '5.0',
#  '1198': '5.0',
#  '1206': '5.0',
#  '1208': '4.0',
#  '1210': '5.0',
#  '1213': '5.0',
#  '1214': '4.0',
#  '1219': '2.0',
#  '1220': '5.0',
#  '1222': '5.0',
#  '1224': '5.0',
#  '1226': '5.0',
#  '1240': '5.0',
#  '1256': '5.0',
#  '1258': '3.0',
#  '1265': '4.0',
#  '1270': '5.0',
#  '1275': '5.0',
#  '1278': '5.0',
#  '1282': '5.0',
#  '1291': '5.0',
#  '1298': '5.0',
#  '1348': '4.0',
#  '1377': '3.0',
#  '1396': '3.0',
#  '1408': '3.0',
#  '1445': '3.0',
#  '1473': '4.0',
#  '1500': '4.0',
#  '1517': '5.0',
#  '1552': '4.0',
#  '1573': '5.0',
#  '1580': '3.0',
#  '1587': '5.0',
#  '1617': '5.0',
#  '1620': '4.0',
#  '1625': '5.0',
#  '1644': '3.0',
#  '1676': '3.0',
#  '1732': '5.0',
#  '1777': '4.0',
#  '1793': '4.0',
#  '1804': '5.0',
#  '1805': '4.0',
#  '1920': '4.0',
#  '1927': '5.0',
#  '1954': '5.0',
#  '1967': '4.0',
#  '2000': '4.0',
#  '2005': '5.0',
#  '2012': '4.0',
#  '2018': '5.0',
#  '2028': '4.0',
#  '2033': '5.0',
#  '2046': '4.0',
#  '2048': '5.0',
#  '2054': '4.0',
#  '2058': '5.0',
#  '2078': '5.0',
#  '2090': '5.0',
#  '2093': '3.0',
#  '2094': '5.0',
#  '2096': '4.0',
#  '2099': '4.0',
#  '2105': '4.0',
#  '2115': '5.0',
#  '2116': '5.0',
#  '2137': '5.0',
#  '2139': '5.0',
#  '2141': '5.0',
#  '2143': '4.0',
#  '2161': '5.0',
#  '2174': '4.0',
#  '2193': '4.0',
#  '2253': '2.0',
#  '2268': '4.0',
#  '2273': '4.0',
#  '2291': '5.0',
#  '2329': '5.0',
#  '2338': '2.0',
#  '2353': '5.0',
#  '2366': '4.0',
#  '2387': '5.0',
#  '2389': '2.0',
#  '2395': '5.0',
#  '2406': '4.0',
#  '2414': '3.0',
#  '2427': '5.0',
#  '2450': '4.0',
#  '2459': '5.0',
#  '2470': '5.0',
#  '2478': '4.0',
#  '2492': '4.0',
#  '2502': '5.0',
#  '2528': '3.0',
#  '2529': '5.0',
#  '2542': '5.0',
#  '2571': '5.0',
#  '2580': '5.0',
#  '2596': '5.0',
#  '2616': '4.0',
#  '2617': '2.0',
#  '2628': '4.0',
#  '2640': '4.0',
#  '2641': '5.0',
#  '2644': '4.0',
#  '2648': '4.0',
#  '2654': '5.0',
#  '2657': '3.0',
#  '2692': '5.0',
#  '2700': '5.0',
#  '2716': '5.0',
#  '2761': '5.0',
#  '2797': '4.0',
#  '2826': '4.0',
#  '2858': '5.0',
#  '2872': '5.0',
#  '2899': '5.0',
#  '2916': '4.0',
#  '2944': '5.0',
#  '2947': '5.0',
#  '2948': '5.0',
#  '2949': '5.0',
#  '2959': '5.0',
#  '2985': '4.0',
#  '2987': '5.0',
#  '2991': '5.0',
#  '2993': '5.0',
#  '2997': '4.0',
#  '3033': '5.0',
#  '3034': '5.0',
#  '3052': '5.0',
#  '3053': '5.0',
#  '3062': '4.0',
#  '3147': '5.0',
#  '3168': '4.0',
#  '3176': '1.0',
#  '3243': '3.0',
#  '3247': '3.0',
#  '3253': '5.0',
#  '3273': '5.0',
#  '3386': '5.0',
#  '3439': '4.0',
#  '3440': '4.0',
#  '3441': '5.0',
#  '3448': '5.0',
#  '3450': '5.0',
#  '3479': '4.0',
#  '3489': '4.0',
#  '3527': '4.0',
#  '3578': '5.0',
#  '3617': '4.0',
#  '3639': '4.0',
#  '3671': '5.0',
#  '3702': '5.0',
#  '3703': '5.0',
#  '3729': '5.0',
#  '3740': '4.0',
#  '3744': '4.0',
#  '3793': '5.0',
#  '3809': '4.0',
#  '4006': '4.0',
#  '5060': '5.0'}

# %%
#q22: What is the average rating for the movie with id 34?
def get_avg_rating():
    ratings_list = []
    json_list = get_names(directory_path)
    for file in json_list:
        file_path = os.path.join("users", file) 
        total_data = read_json(file_path)
        for key in total_data:
            if key == "34":
                ratings_list.append(float(total_data[key]))
    return statistics.mean(ratings_list)
                    
get_avg_rating()
# Out:
# 4.333333333333333

# %% [markdown]
# ### Question 23: What is the *minimum rating* for the movie *Batman (1989)*?
# - You can find the names of the movies in the CSV file.
# - Make sure to use *os.path.join* while opening the file and do not hardcode the slashes!
# - You have to combine the data from the CSV file with the data from the JSON files.
# - Your cell should output a float

# %%
movies = read_csv(os.path.join('data', 'movies.csv'))

# %%
csv_movies = read_csv(os.path.join('data', 'movies.csv'))
headers = csv_movies[0]
data = csv_movies[1:]

# %%
movie_dict = {}
movies = []
for header in headers:
    movie_dict[header] = ''
    
for movie in data:
    movie_dict = {}
    movie_dict['movieId'] = movie[0]  
    movie_dict['title'] = movie[1]
    movie_dict['genres'] = movie[2]
    movies.append(movie_dict)

# %%
#q23: What is the *minimum rating* for the movie *Batman (1989)*?
def get_movieid(title):
    for movie in movies:
        if movie['title'] == title:
            return movie['movieId']

def get_min_rating(movie_id):
    ratings_list = []
    json_list = get_names(directory_path)
    for file in json_list:
        file_path = os.path.join("users", file) 
        total_data = read_json(file_path)
        for key in total_data:
            if key == movie_id:
                ratings_list.append(float(total_data[key]))
    return sorted(ratings_list)[0]
get_min_rating(get_movieid("Batman (1989)"))
# Out:
# 3.0

# %% [markdown]
# ## Analysing countries.db - same dataset as P10 (q24 to q27).
# ## Questions q24 to q27 address topics covered by project P10.
# - Create a sqlite connection to this database.
# - You can use either SQL querries or Pandas statements to answer the following questions.

# %%
path = "countries.db"
assert os.path.exists(path)
conn = sqlite3.connect(path)

# %%
pd.read_sql("select * from sqlite_master", conn)
# Out:
#     type       name   tbl_name  rootpage  \
# 0  table   capitals   capitals         8
# 1  table  countries  countries         2
#
#                                                  sql
# 0  CREATE TABLE "capitals" (\n"capital" TEXT,\n  ...
# 1  CREATE TABLE "countries" (\n"area" INTEGER,\n ...

# %%
capitals = pd.read_sql("select * from capitals", conn)

# %%
countries = pd.read_sql("select * from countries", conn)

# %%
def qry(sql):
    return pd.read_sql(sql, conn)

# %% [markdown]
# ### Question 24: What is the *capital* of *Namibia*?
# - Answer as a python string

# %%
#q24: What is the capital of Namibia?
namibia_capital = qry("""
SELECT capital
FROM capitals
WHERE country = "Namibia"
""")
namibia_capital['capital'].iloc[0]
# Out:
# 'Windhoek'

# %% [markdown]
# ### Question 25: What is the *population* of *each continent*?
# - Answer as a Pandas Dataframe, sorted by population from highest to lowest.
# - The image in the cell below shows the first two lines of the resulting DataFrame.

# %%
#q25 What is the population of each continent?
continent_population_df = qry("""
SELECT continent, SUM(population) AS "population"
FROM countries
GROUP BY continent
ORDER BY "population" DESC
""")
continent_population_df
# Out:
#        continent  population
# 0           Asia  3739902863
# 1         Africa   824954038
# 2         Europe   792053486
# 3  North America   515041558
# 4  South America   375441666
# 5      Australia    32163025

# %% [markdown]
# <img population_of_continent.png>

# %% [markdown]
# <img src="population_of_continent.png">

# %%
# %matplotlib inline

# %% [markdown]
# ### Question 26: *Plot the total population* of each continent.
# - Prepare a bar plot.
# - Put continents on the x-axis and total area on the y-axis.
# - The continents should be sorted along the x-axis alphabetically.

# %%
# q26 Plot the total population of each continent? 
continent_population = continent_population_df.set_index("continent")
countries_bar_ax = continent_population.plot.bar(color = "0")
countries_bar_ax.set_ylabel("total population")
countries_bar_ax.set_xlabel("continent")
# Out:
# Text(0.5, 0, 'continent')

# %% [markdown]
# ### Question 27: What is the *population density (population / area)* of all the *top 7* most dense *countries in Europe*?
# - Report these as a Pandas DataFrame sorted in decreasing order of population density.
# - The image below shows the first 3.

# %%
#q27 What is the population density (population / area) of all the top 7 most 
# dense countries in Europe. 
qry("""
SELECT country, (population / area) AS "population density"
FROM countries
WHERE continent = "Europe"
ORDER BY "population density" DESC
LIMIT 7
""")
# Out:
#           country  population density
# 0          Monaco               16271
# 1           Malta                1266
# 2      San Marino                 479
# 3     Netherlands                 397
# 4         Belgium                 339
# 5  United Kingdom                 247
# 6         Germany                 230

# %% [markdown]
# <img src="population_density.png">

# %%
# Close the connection to the database
# Write your code here
conn.close()

# %% [markdown]
# ### Congratulations, you are all done with work for CS220 course :) Mike and Meena wish you the best of luck for a bright future.
